# %% [markdown]
# # Data Science: Project 3
# ##  Gradient Descent and Gradient Boosting
# ### Jacob Goodman and Alan Leidner
# #### Dec 5, 2021
# Assignment: https://yu.instructure.com/courses/50398/assignments/191963

# %% [markdown]
# # Introduction
#
# In this notebook, we will compare the performance of multiple classification models, from decision trees to XGBoost models. The data set we will be working with is the dataset we first engaged within Project 1. The dataset is comprised of more than 73,000 observations, each of which pertains to a particular NY State school district and associated subgroupings/categorizations of high school students who had been enrolled for at least 4 years as of the end of the 2018-2019 school year.
#
# The response variable we will be modeling will be a categorical indicator variable derived from the dataset’s dropout_pct attribute.

# %% [markdown]
# ## Attribute Information
# 0. report_school_year: Indicates school year for which high school graduation info is being reported
# 1. aggregation_index: Numeric code identifying manner in which high school graduation data has been aggregated
# 2. aggregation_type: Text description of how high school graduation data has been aggregated
# 3. aggregation_name:
# 4. nrc_code: Numeric code identifying "needs / resource capacity", which is an indicator of the type of school district
# 5. nrc_desc: Text description of the type of school district
# 6. county_code: Numeric code for county name
# 7. county_name: Full name of applicable NY State county
# 8. nyc_ind: Indicates whether or not the school district resides within the borders of NYC
# 9. membership_desc: Indicates school year in which students first enrolled in High School
# 10. subgroup_code: Numeric code identifying student subgrouping
# 11. subgroup_name: Text description of student subgrouping. Note that a student may belong to MORE THAN ONE subgrouping (e.g., "Female", "Hispanic", "Not English Language Learner", etc.)
# 12. enroll_cnt: How many students of the indicated subgrouping were enrolled during the given school year
# 13. grad_cnt: How many enrolled students of the indicated subgrouping graduated at the end of the given school year
# 14. grad_pct: What percentage of enrolled students of the indicated subgrouping graduated at the end for the given school year
# 15. local_cnt: How many enrolled students of the indicated subgrouping were awarded a "Local" diploma
# 16. local_pct: What percentage of enrolled students of the indicated subgrouping were awarded a "Local" diploma
# 17. reg_cnt: How many enrolled students of the indicated subgrouping were awarded a "Regents" diploma
# 18. reg_pct: What percentage of enrolled students of the indicated subgrouping were awarded a "Regents" diploma
# 19. reg_adv_cnt: How many enrolled students of the indicated subgrouping were awarded a "Regents Advanced" diploma
# 20. reg_adv_pct: What percentage of enrolled students of the indicated subgrouping were awarded a "Regents Advanced" diploma
# 21. non_diploma_credential_cnt: How many enrolled students of the indicated subgrouping achieved a non-diploma credential
# 22. non_diploma_credential_pct: What percentage of enrolled students of the indicated subgrouping achieved a non-diploma credential
# 23. still_enrolled_cnt: How many enrolled students of the indicated subgrouping did not graduate but were still_enrolled
# 24. still_enrolled_pct: What percentage of enrolled students of the indicated subgrouping did not graduate but were still_enrolled
# 25. ged_cnt: How many enrolled students of the indicated subgrouping were awarded a "GED" diploma
# 26. ged_pct: What percentage of enrolled students of the indicated subgrouping were awarded a "GED" diploma
# 27. dropout_cnt: How many enrolled students of the indicated subgrouping discontinued their high school enrollment during the school year
# 28. dropout_pct: What percentage of enrolled students of the indicated subgrouping discontinued their high school enrollment during the school year

# %%
#Import packages for data frames 
import numpy as np
import pandas as pd

#Import pyplot and seaborn for graph creating
import matplotlib.pyplot as plt
import seaborn as sns 

#Importing to dummy categorical data
from patsy import dmatrix

#This ingores depreciation warnings, which will make the code more readable
import warnings 
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# # Exploratory Data Analysis
# The dataset was loaded into the DAV 6150 Github Repository for Project1 here: https://raw.githubusercontent.com/yuleidner/DAV-6150/main/M6/Project1_Data.csv. This notebook will now load the csv into a Pandas dataframe for analysis.

# %%
# read a set of sample data from github. It contains information related to cars and insurance
filename = "https://raw.githubusercontent.com/yuleidner/DAV-6150/main/M6/Project1_Data.csv"
df = pd.read_csv(filename)
pd.set_option('display.max_columns', None) #expands df to display all columns
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>report_school_year</th>
#       <th>aggregation_index</th>
#       <th>aggregation_type</th>
#       <th>aggregation_name</th>
#       <th>nrc_code</th>
#       <th>nrc_desc</th>
#       <th>county_code</th>
#       <th>county_name</th>
#       <th>nyc_ind</th>
#       <th>membership_desc</th>
#       <th>subgroup_code</th>
#       <th>subgroup_name</th>
#       <th>enroll_cnt</th>
#       <th>grad_cnt</th>
#       <th>grad_pct</th>
#       <th>local_cnt</th>
#       <th>local_pct</th>
#       <th>reg_cnt</th>
#       <th>reg_pct</th>
#       <th>reg_adv_cnt</th>
#       <th>reg_adv_pct</th>
#       <th>non_diploma_credential_cnt</th>
#       <th>non_diploma_credential_pct</th>
#       <th>still_enr_cnt</th>
#       <th>still_enr_pct</th>
#       <th>ged_cnt</th>
#       <th>ged_pct</th>
#       <th>dropout_cnt</th>
#       <th>dropout_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2018-19</td>
#       <td>3</td>
#       <td>District</td>
#       <td>ALBANY CITY SCHOOL DISTRICT</td>
#       <td>3</td>
#       <td>Urban-Suburban High Needs</td>
#       <td>1</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>1</td>
#       <td>All Students</td>
#       <td>658</td>
#       <td>464</td>
#       <td>71%</td>
#       <td>63</td>
#       <td>10%</td>
#       <td>310</td>
#       <td>47%</td>
#       <td>91</td>
#       <td>14%</td>
#       <td>16</td>
#       <td>2%</td>
#       <td>30</td>
#       <td>5%</td>
#       <td>0</td>
#       <td>0%</td>
#       <td>148</td>
#       <td>22%</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2018-19</td>
#       <td>3</td>
#       <td>District</td>
#       <td>ALBANY CITY SCHOOL DISTRICT</td>
#       <td>3</td>
#       <td>Urban-Suburban High Needs</td>
#       <td>1</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>2</td>
#       <td>Female</td>
#       <td>324</td>
#       <td>246</td>
#       <td>76%</td>
#       <td>30</td>
#       <td>9%</td>
#       <td>169</td>
#       <td>52%</td>
#       <td>47</td>
#       <td>15%</td>
#       <td>2</td>
#       <td>1%</td>
#       <td>11</td>
#       <td>3%</td>
#       <td>0</td>
#       <td>0%</td>
#       <td>65</td>
#       <td>20%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2018-19</td>
#       <td>3</td>
#       <td>District</td>
#       <td>ALBANY CITY SCHOOL DISTRICT</td>
#       <td>3</td>
#       <td>Urban-Suburban High Needs</td>
#       <td>1</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>3</td>
#       <td>Male</td>
#       <td>334</td>
#       <td>218</td>
#       <td>65%</td>
#       <td>33</td>
#       <td>10%</td>
#       <td>141</td>
#       <td>42%</td>
#       <td>44</td>
#       <td>13%</td>
#       <td>14</td>
#       <td>4%</td>
#       <td>19</td>
#       <td>6%</td>
#       <td>0</td>
#       <td>0%</td>
#       <td>83</td>
#       <td>25%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2018-19</td>
#       <td>3</td>
#       <td>District</td>
#       <td>ALBANY CITY SCHOOL DISTRICT</td>
#       <td>3</td>
#       <td>Urban-Suburban High Needs</td>
#       <td>1</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>4</td>
#       <td>American Indian/Alaska Native</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2018-19</td>
#       <td>3</td>
#       <td>District</td>
#       <td>ALBANY CITY SCHOOL DISTRICT</td>
#       <td>3</td>
#       <td>Urban-Suburban High Needs</td>
#       <td>1</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>5</td>
#       <td>Black</td>
#       <td>367</td>
#       <td>248</td>
#       <td>68%</td>
#       <td>42</td>
#       <td>11%</td>
#       <td>183</td>
#       <td>50%</td>
#       <td>23</td>
#       <td>6%</td>
#       <td>10</td>
#       <td>3%</td>
#       <td>18</td>
#       <td>5%</td>
#       <td>0</td>
#       <td>0%</td>
#       <td>91</td>
#       <td>25%</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Data Validation

# %%
## a few methods will now be called to view summaries of this dataframe
df.shape
# Out:
# (73152, 29)

# %% [markdown]
# Nothing surprising here, but it did help us catch aggregation_name, which we missed in our first review of Attribute Information.
# #### Character Cleanup

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73152 entries, 0 to 73151
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   report_school_year          73152 non-null  object
#  1   aggregation_index           73152 non-null  int64
#  2   aggregation_type            73152 non-null  object
#  3   aggregation_name            73152 non-null  object
#  4   nrc_code                    73152 non-null  int64
#  5   nrc_desc                    73152 non-null  object
#  6   county_code                 73152 non-null  int64
#  7   county_name                 73152 non-null  object
#  8   nyc_ind                     73152 non-null  int64
#  9   membership_desc             73152 non-null  object
#  10  subgroup_code               73152 non-null  int64
#  11  subgroup_name               73152 non-null  object
#  12  enroll_cnt                  73152 non-null  object
#  13  grad_cnt                    73152 non-null  object
#  14  grad_pct                    73152 non-null  object
#  15  local_cnt                   73152 non-null  object
#  16  local_pct                   73152 non-null  object
#  17  reg_cnt                     73152 non-null  object
#  18  reg_pct                     73152 non-null  object
#  19  reg_adv_cnt                 73152 non-null  object
#  20  reg_adv_pct                 73152 non-null  object
#  21  non_diploma_credential_cnt  73152 non-null  object
#  22  non_diploma_credential_pct  73152 non-null  object
#  23  still_enr_cnt               73152 non-null  object
#  24  still_enr_pct               73152 non-null  object
#  25  ged_cnt                     73152 non-null  object
#  26  ged_pct                     73152 non-null  object
#  27  dropout_cnt                 73152 non-null  object
#  28  dropout_pct                 73152 non-null  object
# dtypes: int64(5), object(24)
# memory usage: 16.2+ MB

# %% [markdown]
# Although the info() function is reporting that there are no "null" responses, we can see in our head() function that at least some values are using  '-' instead. We will replace those strings using np.nan values now.

# %%
df = df.replace('-', np.nan)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73152 entries, 0 to 73151
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   report_school_year          73152 non-null  object
#  1   aggregation_index           73152 non-null  int64
#  2   aggregation_type            73152 non-null  object
#  3   aggregation_name            73152 non-null  object
#  4   nrc_code                    73152 non-null  int64
#  5   nrc_desc                    73152 non-null  object
#  6   county_code                 73152 non-null  int64
#  7   county_name                 73152 non-null  object
#  8   nyc_ind                     73152 non-null  int64
#  9   membership_desc             73152 non-null  object
#  10  subgroup_code               73152 non-null  int64
#  11  subgroup_name               73152 non-null  object
#  12  enroll_cnt                  39674 non-null  object
#  13  grad_cnt                    39674 non-null  object
#  14  grad_pct                    39674 non-null  object
#  15  local_cnt                   39674 non-null  object
#  16  local_pct                   39674 non-null  object
#  17  reg_cnt                     39674 non-null  object
#  18  reg_pct                     39674 non-null  object
#  19  reg_adv_cnt                 39674 non-null  object
#  20  reg_adv_pct                 39674 non-null  object
#  21  non_diploma_credential_cnt  39674 non-null  object
#  22  non_diploma_credential_pct  39674 non-null  object
#  23  still_enr_cnt               39674 non-null  object
#  24  still_enr_pct               39674 non-null  object
#  25  ged_cnt                     39674 non-null  object
#  26  ged_pct                     39674 non-null  object
#  27  dropout_cnt                 39674 non-null  object
#  28  dropout_pct                 39674 non-null  object
# dtypes: int64(5), object(24)
# memory usage: 16.2+ MB

# %% [markdown]
# #### Datatype Cleanup
# We also notice that the dtype assigned from the pandas import does not meet our expectations, likely due to the '-' character in the columns used instead of Nan. We will now convert the columns to the appropriate dtypes. First, we must remove all of the '%' characters.

# %%
pct_columns = ['grad_pct','local_pct','reg_pct','reg_adv_pct','non_diploma_credential_pct','still_enr_pct','ged_pct','dropout_pct']

for p  in pct_columns:
  df[p] = df[p].str.replace('%', '')
  
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>report_school_year</th>
#       <th>aggregation_index</th>
#       <th>aggregation_type</th>
#       <th>aggregation_name</th>
#       <th>nrc_code</th>
#       <th>nrc_desc</th>
#       <th>county_code</th>
#       <th>county_name</th>
#       <th>nyc_ind</th>
#       <th>membership_desc</th>
#       <th>subgroup_code</th>
#       <th>subgroup_name</th>
#       <th>enroll_cnt</th>
#       <th>grad_cnt</th>
#       <th>grad_pct</th>
#       <th>local_cnt</th>
#       <th>local_pct</th>
#       <th>reg_cnt</th>
#       <th>reg_pct</th>
#       <th>reg_adv_cnt</th>
#       <th>reg_adv_pct</th>
#       <th>non_diploma_credential_cnt</th>
#       <th>non_diploma_credential_pct</th>
#       <th>still_enr_cnt</th>
#       <th>still_enr_pct</th>
#       <th>ged_cnt</th>
#       <th>ged_pct</th>
#       <th>dropout_cnt</th>
#       <th>dropout_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2018-19</td>
#       <td>3</td>
#       <td>District</td>
#       <td>ALBANY CITY SCHOOL DISTRICT</td>
#       <td>3</td>
#       <td>Urban-Suburban High Needs</td>
#       <td>1</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>1</td>
#       <td>All Students</td>
#       <td>658</td>
#       <td>464</td>
#       <td>71</td>
#       <td>63</td>
#       <td>10</td>
#       <td>310</td>
#       <td>47</td>
#       <td>91</td>
#       <td>14</td>
#       <td>16</td>
#       <td>2</td>
#       <td>30</td>
#       <td>5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>148</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2018-19</td>
#       <td>3</td>
#       <td>District</td>
#       <td>ALBANY CITY SCHOOL DISTRICT</td>
#       <td>3</td>
#       <td>Urban-Suburban High Needs</td>
#       <td>1</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>2</td>
#       <td>Female</td>
#       <td>324</td>
#       <td>246</td>
#       <td>76</td>
#       <td>30</td>
#       <td>9</td>
#       <td>169</td>
#       <td>52</td>
#       <td>47</td>
#       <td>15</td>
#       <td>2</td>
#       <td>1</td>
#       <td>11</td>
#       <td>3</td>
#       <td>0</td>
#       <td>0</td>
#       <td>65</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2018-19</td>
#       <td>3</td>
#       <td>District</td>
#       <td>ALBANY CITY SCHOOL DISTRICT</td>
#       <td>3</td>
#       <td>Urban-Suburban High Needs</td>
#       <td>1</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>3</td>
#       <td>Male</td>
#       <td>334</td>
#       <td>218</td>
#       <td>65</td>
#       <td>33</td>
#       <td>10</td>
#       <td>141</td>
#       <td>42</td>
#       <td>44</td>
#       <td>13</td>
#       <td>14</td>
#       <td>4</td>
#       <td>19</td>
#       <td>6</td>
#       <td>0</td>
#       <td>0</td>
#       <td>83</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2018-19</td>
#       <td>3</td>
#       <td>District</td>
#       <td>ALBANY CITY SCHOOL DISTRICT</td>
#       <td>3</td>
#       <td>Urban-Suburban High Needs</td>
#       <td>1</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>4</td>
#       <td>American Indian/Alaska Native</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2018-19</td>
#       <td>3</td>
#       <td>District</td>
#       <td>ALBANY CITY SCHOOL DISTRICT</td>
#       <td>3</td>
#       <td>Urban-Suburban High Needs</td>
#       <td>1</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>5</td>
#       <td>Black</td>
#       <td>367</td>
#       <td>248</td>
#       <td>68</td>
#       <td>42</td>
#       <td>11</td>
#       <td>183</td>
#       <td>50</td>
#       <td>23</td>
#       <td>6</td>
#       <td>10</td>
#       <td>3</td>
#       <td>18</td>
#       <td>5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>91</td>
#       <td>25</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cnt_columns = ['enroll_cnt','grad_cnt','local_cnt','reg_cnt','reg_adv_cnt','non_diploma_credential_cnt','still_enr_cnt','ged_cnt','dropout_cnt']
num_categorical = ['aggregation_index','nrc_code','county_code','nyc_ind','subgroup_code']
for c in cnt_columns+pct_columns+num_categorical:
  df[c] = pd.to_numeric(df[c])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73152 entries, 0 to 73151
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   report_school_year          73152 non-null  object
#  1   aggregation_index           73152 non-null  int64
#  2   aggregation_type            73152 non-null  object
#  3   aggregation_name            73152 non-null  object
#  4   nrc_code                    73152 non-null  int64
#  5   nrc_desc                    73152 non-null  object
#  6   county_code                 73152 non-null  int64
#  7   county_name                 73152 non-null  object
#  8   nyc_ind                     73152 non-null  int64
#  9   membership_desc             73152 non-null  object
#  10  subgroup_code               73152 non-null  int64
#  11  subgroup_name               73152 non-null  object
#  12  enroll_cnt                  39674 non-null  float64
#  13  grad_cnt                    39674 non-null  float64
#  14  grad_pct                    39674 non-null  float64
#  15  local_cnt                   39674 non-null  float64
#  16  local_pct                   39674 non-null  float64
#  17  reg_cnt                     39674 non-null  float64
#  18  reg_pct                     39674 non-null  float64
#  19  reg_adv_cnt                 39674 non-null  float64
#  20  reg_adv_pct                 39674 non-null  float64
#  21  non_diploma_credential_cnt  39674 non-null  float64
#  22  non_diploma_credential_pct  39674 non-null  float64
#  23  still_enr_cnt               39674 non-null  float64
#  24  still_enr_pct               39674 non-null  float64
#  25  ged_cnt                     39674 non-null  float64
#  26  ged_pct                     39674 non-null  float64
#  27  dropout_cnt                 39674 non-null  float64
#  28  dropout_pct                 39674 non-null  float64
# dtypes: float64(17), int64(5), object(7)
# memory usage: 16.2+ MB

# %%
#We are going to look at the statistical analysis of our data
df.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>aggregation_index</th>
#       <th>nrc_code</th>
#       <th>county_code</th>
#       <th>nyc_ind</th>
#       <th>subgroup_code</th>
#       <th>enroll_cnt</th>
#       <th>grad_cnt</th>
#       <th>grad_pct</th>
#       <th>local_cnt</th>
#       <th>local_pct</th>
#       <th>reg_cnt</th>
#       <th>reg_pct</th>
#       <th>reg_adv_cnt</th>
#       <th>reg_adv_pct</th>
#       <th>non_diploma_credential_cnt</th>
#       <th>non_diploma_credential_pct</th>
#       <th>still_enr_cnt</th>
#       <th>still_enr_pct</th>
#       <th>ged_cnt</th>
#       <th>ged_pct</th>
#       <th>dropout_cnt</th>
#       <th>dropout_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>73152.0</td>
#       <td>73152.000000</td>
#       <td>73152.000000</td>
#       <td>73152.000000</td>
#       <td>73152.000000</td>
#       <td>39674.000000</td>
#       <td>39674.000000</td>
#       <td>39674.000000</td>
#       <td>39674.000000</td>
#       <td>39674.000000</td>
#       <td>39674.000000</td>
#       <td>39674.000000</td>
#       <td>39674.000000</td>
#       <td>39674.000000</td>
#       <td>39674.000000</td>
#       <td>39674.000000</td>
#       <td>39674.000000</td>
#       <td>39674.000000</td>
#       <td>39674.000000</td>
#       <td>39674.000000</td>
#       <td>39674.000000</td>
#       <td>39674.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>3.0</td>
#       <td>4.588583</td>
#       <td>36.251859</td>
#       <td>0.055255</td>
#       <td>12.000930</td>
#       <td>192.120079</td>
#       <td>161.178354</td>
#       <td>84.406614</td>
#       <td>12.340903</td>
#       <td>8.479936</td>
#       <td>86.804708</td>
#       <td>43.371125</td>
#       <td>62.032742</td>
#       <td>32.577204</td>
#       <td>1.924485</td>
#       <td>1.742627</td>
#       <td>11.299516</td>
#       <td>5.190704</td>
#       <td>1.377577</td>
#       <td>0.612693</td>
#       <td>16.239225</td>
#       <td>7.963049</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.0</td>
#       <td>1.203507</td>
#       <td>20.588044</td>
#       <td>0.228479</td>
#       <td>7.213138</td>
#       <td>439.972474</td>
#       <td>361.294773</td>
#       <td>15.679500</td>
#       <td>32.046302</td>
#       <td>10.398486</td>
#       <td>225.795826</td>
#       <td>17.124891</td>
#       <td>132.777866</td>
#       <td>23.001197</td>
#       <td>6.498913</td>
#       <td>4.063987</td>
#       <td>40.766672</td>
#       <td>8.832710</td>
#       <td>4.949389</td>
#       <td>1.985445</td>
#       <td>50.129834</td>
#       <td>9.658698</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>3.0</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>5.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>3.0</td>
#       <td>4.000000</td>
#       <td>17.000000</td>
#       <td>0.000000</td>
#       <td>6.000000</td>
#       <td>25.000000</td>
#       <td>20.000000</td>
#       <td>79.000000</td>
#       <td>1.000000</td>
#       <td>2.000000</td>
#       <td>10.000000</td>
#       <td>33.000000</td>
#       <td>4.000000</td>
#       <td>14.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>3.0</td>
#       <td>5.000000</td>
#       <td>40.000000</td>
#       <td>0.000000</td>
#       <td>11.000000</td>
#       <td>66.000000</td>
#       <td>57.000000</td>
#       <td>89.000000</td>
#       <td>4.000000</td>
#       <td>6.000000</td>
#       <td>27.000000</td>
#       <td>43.000000</td>
#       <td>18.000000</td>
#       <td>31.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>2.000000</td>
#       <td>2.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>3.000000</td>
#       <td>5.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>3.0</td>
#       <td>5.000000</td>
#       <td>57.000000</td>
#       <td>0.000000</td>
#       <td>18.000000</td>
#       <td>179.000000</td>
#       <td>156.000000</td>
#       <td>95.000000</td>
#       <td>10.000000</td>
#       <td>11.000000</td>
#       <td>69.000000</td>
#       <td>53.000000</td>
#       <td>62.000000</td>
#       <td>49.000000</td>
#       <td>2.000000</td>
#       <td>2.000000</td>
#       <td>5.000000</td>
#       <td>6.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>9.000000</td>
#       <td>11.000000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>3.0</td>
#       <td>6.000000</td>
#       <td>68.000000</td>
#       <td>1.000000</td>
#       <td>25.000000</td>
#       <td>9176.000000</td>
#       <td>7540.000000</td>
#       <td>100.000000</td>
#       <td>557.000000</td>
#       <td>100.000000</td>
#       <td>4752.000000</td>
#       <td>100.000000</td>
#       <td>2231.000000</td>
#       <td>100.000000</td>
#       <td>279.000000</td>
#       <td>67.000000</td>
#       <td>1381.000000</td>
#       <td>100.000000</td>
#       <td>97.000000</td>
#       <td>67.000000</td>
#       <td>1091.000000</td>
#       <td>100.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Null Visualization

# %%
#null visualization
sns.set(rc={'figure.figsize':(15,5)})
sns.heatmap(df.isnull(), cmap='viridis');

# %% [markdown]
# 50% of our target variable is missing, which is troubling. The missing data in the cnt/pct features line up with our missing target perfectly. We will have to perform some analyses to see if these missing values are correlated with categorical values. There doesn't seem to be a unique key in the dataset for us to check to see if there are duplicates. We may need to drop all rows with the missing target variable: it is too large of a group to impute.

# %% [markdown]
# ### Custom function
# We find ourselves turning to the same methods and visualizations for univariate analysis. The following function will be utilized to standardize our EDA and simplify code.

# %%
def distbox (i,df, type = 'numeric', xlabelrotation = 0, normalize=True):
  """ 
  This function is designed to provide distribution statics and visualizations of dataframe columns
  it takes in a column number and dataframe and can return:
   numerical output -
            1. the skewness of the column
            2. the kurtosis or spread
            3. the descriptive statistics from .describe()
            4. a histogram and boxplot
            
  OR categorical -        
            1. countplot
            2. values counts (either count or as percentages)
  """
  #best practice import dependencies in functions
  import numpy as np
  import pandas as pd
  import matplotlib.pyplot as plt
  import seaborn as sns
  import warnings 
  warnings.filterwarnings("ignore", category=FutureWarning)
  c = df.iloc[:,i]
  plt.figure(figsize=(8,4))
  if type =='numeric':
    plt.subplot(1,2,1);#Histogram location
    sns.distplot(c);#calls a histogram
    plt.title(df.columns[i]);#adds title
    plt.subplot(1,2,2);#Boxplot location
    sns.boxplot(c);#calls a box and whisket plot
    plt.title(df.columns[i]);#adds title
    print("Skewness: %f" %c.skew()) #Adds Skew value
    # If the skewness is between -0.5 and 0.5, the data are fairly symmetrical
    # If the skewness is between -1 and — 0.5 or between 0.5 and 1, the data are moderately skewed
    # If the skewness is less than -1 or greater than 1, the data are highly skewed
    print("Kurtosis: %f" %c.kurt(skipna = True)) #Adds Kurtosis value (tail-ness)
    # While kurtosis determines the heaviness of the distribution tails.
    # Kurtosis > 3 thin and not spread
    # Kurtosis <3 moderate spread
    print(c.describe()) #Adds summary statistics of the variable


  elif type == 'categorical':
    sns.countplot(c)
    plt.title(df.columns[i]);#adds title
    plt.xticks(rotation = xlabelrotation)#rotates x-labels
    print(c.value_counts(normalize=normalize))

  print("Nullcount: %f" %c.isnull().sum().sum())
  plt.show() # this will load image to console before executing next line of code

# %% [markdown]
# ### dropout_pct (TARGET)
#
# What percentage of enrolled students of the indicated subgrouping was awarded a "Regents" diploma

# %%
distbox(28,df)
# Out:
# Skewness: 2.493681
# Kurtosis: 9.467020
# count    39674.000000
# mean         7.963049
# std          9.658698
# min          0.000000
# 25%          1.000000
# 50%          5.000000
# 75%         11.000000
# max        100.000000
# Name: dropout_pct, dtype: float64
# Nullcount: 33478.000000

# %% [markdown]
# The response variable is skewed right, and not very Gaussian. Outliers here may have an outsized effect on the shape and skew.
#
# ### dropout_cnt

# %%
distbox(27,df)
# Out:
# Skewness: 7.119012
# Kurtosis: 73.834067
# count    39674.000000
# mean        16.239225
# std         50.129834
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          9.000000
# max       1091.000000
# Name: dropout_cnt, dtype: float64
# Nullcount: 33478.000000

# %% [markdown]
# This is skewed heavily to the right with many outliers.
#
# conclusions:
#
# We will drop this column to prevent information leaks in the models.
#
# ### report_school_year

# %% [markdown]
# All rows are entries for the same year. This may be useful when performing analyses across years, but is not relevant in our context. We will drop this column.
#
# ### aggregation_index

# %%
df.aggregation_index.value_counts()

# %% [markdown]
# All rows are entries for the same aggregation type. This may be useful when performing analyses across datasets, but is not relevant in our context. We will drop this column.
# ### aggregation_type

# %%
df.aggregation_type.value_counts()

# %% [markdown]
# All entries have been aggregated by District. This may be useful when performing analyses across datasets, but is not relevant in our context. We will drop this column.
#
# ### aggregation_name

# %%
df.aggregation_name.value_counts()

# %%
len(pd.unique(df['aggregation_name']))
# Out:
# 680

# %% [markdown]
# This may be a useful categorical feature that identifies the district of each student. The large number of values means that we will have to employ some grouping techniques such as hashing.
#
# ### nrc_code/nrc_desc
#
# This is a code and description of the type of school district.

# %%
df.nrc_code.value_counts()

# %% [markdown]
# We can see there is quite a difference between these types of school districts. We will now match the numeric value to the description of these 'nrc' categories.

# %%
#group all nrc_code values by group, and then assign the appropriate desc for unique values
nrc_group = df.groupby('nrc_code')
nrc = nrc_group.apply(lambda x: x['nrc_desc'].unique())

nrc

# %%
#visualize groups
sns.set(rc={'figure.figsize':(18,5)})
sns.countplot(df.nrc_desc);

# %% [markdown]
# The nrc attribute identifies "needs / resource capacity", or the type of school district. The distribution may be something to watch out for in terms of representation in the training/validation split for data models. This feature seems to be partially rank ordered, but not completely.
#
# conclusions:
# drop nrc_code and handle nrc_desc carefully
# ### county_code/county_name

# %%
#group all county_code values by group, and then assign the appropriate desc for unique values
county_group = df.groupby('county_code')
county = county_group.apply(lambda x: x['county_name'].unique())

county

# %%
#visualize groups
sns.set(rc={'figure.figsize':(20,10)})
plt.xticks(rotation=90)
sns.countplot(df.county_name);

# %% [markdown]
# We see a wide gap between the number of entries per county
#
# Conclusion:
#
# Drop county_code, treat county_name with care
# ### nyc_ind

# %%
distbox(8,df,'categorical')
# Out:
# 0    0.944745
# 1    0.055255
# Name: nyc_ind, dtype: float64
# Nullcount: 0.000000

# %% [markdown]
# We expect this feature to be correlated with county_code and nrc_code, but will leave feature selection for a later section. It is unbalanced, but that is ok.
#
# ### membership_desc
# Indicates school year in which students first enrolled in High School

# %%
distbox(9,df, 'categorical',270)
# Out:
# 2015 Total Cohort - 4 Year Outcome                  0.168129
# 2015 Total Cohort - 4 Year Outcome - August 2019    0.168129
# 2014 Total Cohort - 5 Year Outcome                  0.167555
# 2014 Total Cohort - 5 Year Outcome - August 2019    0.167555
# 2013 Total Cohort - 6 Year Outcome                  0.164315
# 2013 Total Cohort - 6 Year Outcome - August 2019    0.164315
# Name: membership_desc, dtype: float64
# Nullcount: 0.000000

# %% [markdown]
# This has a relatively even grouping. We will dummy the feature.
#
# ### subgroup_code/subgroup_name/enroll_cnt
#
# subgroup: Note that a student may belong to MORE THAN ONE subgrouping (e.g., "Female", "Hispanic", "Not English Language Learner", etc.)
#
# enroll_cnt: How many students of the indicated subgrouping were enrolled during the given school year

# %%
#group all subgroup_code values by group, and then assign the appropriate name for unique values
subgroup_group = df.groupby('subgroup_code')
subgroup = subgroup_group.apply(lambda x: x['subgroup_name'].unique())

subgroup

# %%
sg_val = df.subgroup_code.value_counts(sort=False) 
sg_val

# %% [markdown]
# Conclusion:
#
# We have several sparse classes which we may combine. We will drop subgroup_code, a categorical column which is represented by ordinal data at the moment, which we can gather from subgroup_name
#
# ### grad_cnt
#
# How many enrolled students of the indicated subgroup graduated at the end of the given school year

# %%
distbox(13,df)
# Out:
# Skewness: 7.768134
# Kurtosis: 97.521516
# count    39674.000000
# mean       161.178354
# std        361.294773
# min          0.000000
# 25%         20.000000
# 50%         57.000000
# 75%        156.000000
# max       7540.000000
# Name: grad_cnt, dtype: float64
# Nullcount: 33478.000000

# %% [markdown]
# This feature is heavily skewed.
#
# conclusions:
#
# We will normalize and standardize
# ### grad_pct
# What percentage of enrolled students of the indicated subgrouping graduated at the end for the given school year

# %%
distbox(14,df)
# Out:
# Skewness: -1.968723
# Kurtosis: 4.956242
# count    39674.000000
# mean        84.406614
# std         15.679500
# min          0.000000
# 25%         79.000000
# 50%         89.000000
# 75%         95.000000
# max        100.000000
# Name: grad_pct, dtype: float64
# Nullcount: 33478.000000

# %% [markdown]
# It is unusual that grad_pct is left skewed when grad_cnt is right skewed.
#
# conclusions:
#
# We will normalize and standardize.
#
# ### local_cnt

# %%
distbox(15,df)
# Out:
# Skewness: 6.621719
# Kurtosis: 60.720475
# count    39674.000000
# mean        12.340903
# std         32.046302
# min          0.000000
# 25%          1.000000
# 50%          4.000000
# 75%         10.000000
# max        557.000000
# Name: local_cnt, dtype: float64
# Nullcount: 33478.000000

# %% [markdown]
# This is skewed heavily to the right with many outliers.
#
# conclusions:
#
# We will normalize and standardize
#
# ### local_pct

# %%
distbox(16,df)
# Out:
# Skewness: 2.739318
# Kurtosis: 10.641760
# count    39674.000000
# mean         8.479936
# std         10.398486
# min          0.000000
# 25%          2.000000
# 50%          6.000000
# 75%         11.000000
# max        100.000000
# Name: local_pct, dtype: float64
# Nullcount: 33478.000000

# %% [markdown]
# This is skewed heavily to the right with many outliers. It is the same shape as our response variable, so we might expect some predictive value here.
#
# conclusions:
#
# We will normalize and standardize
#
# ### reg_cnt
#
# How many enrolled students of the indicated subgrouping were awarded a "Regents" diploma

# %%
distbox(17,df)
# Out:
# Skewness: 8.059655
# Kurtosis: 102.728247
# count    39674.000000
# mean        86.804708
# std        225.795826
# min          0.000000
# 25%         10.000000
# 50%         27.000000
# 75%         69.000000
# max       4752.000000
# Name: reg_cnt, dtype: float64
# Nullcount: 33478.000000

# %% [markdown]
# analysis:
#
# This is heavily skewed to the right. We will normalize and standardize.
#
# ### reg_pct
#
# What percentage of enrolled students of the indicated subgrouping was awarded a "Regents" diploma

# %%
distbox(18,df)
# Out:
# Skewness: 0.326277
# Kurtosis: 0.869141
# count    39674.000000
# mean        43.371125
# std         17.124891
# min          0.000000
# 25%         33.000000
# 50%         43.000000
# 75%         53.000000
# max        100.000000
# Name: reg_pct, dtype: float64
# Nullcount: 33478.000000

# %% [markdown]
# analysis:
#
# This is a Gaussian distribution. We will standardize it to bring it in line with other features.
#
# ### reg_adv_cnt

# %%
distbox(19,df)
# Out:
# Skewness: 6.255797
# Kurtosis: 60.643494
# count    39674.000000
# mean        62.032742
# std        132.777866
# min          0.000000
# 25%          4.000000
# 50%         18.000000
# 75%         62.000000
# max       2231.000000
# Name: reg_adv_cnt, dtype: float64
# Nullcount: 33478.000000

# %% [markdown]
# This is skewed heavily to the right with many outliers.
#
# conclusions:
#
# We will normalize and standardize
#
# ### reg_adv_pct

# %%
distbox(20,df)
# Out:
# Skewness: 0.333009
# Kurtosis: -0.682708
# count    39674.000000
# mean        32.577204
# std         23.001197
# min          0.000000
# 25%         14.000000
# 50%         31.000000
# 75%         49.000000
# max        100.000000
# Name: reg_adv_pct, dtype: float64
# Nullcount: 33478.000000

# %% [markdown]
# This is relatively Gaussian.
#
# We will normalize it to keep it in line with other features.

# %% [markdown]
# ### non_diploma_credential_cnt

# %%
distbox(21,df)
# Out:
# Skewness: 17.986157
# Kurtosis: 582.359345
# count    39674.000000
# mean         1.924485
# std          6.498913
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          2.000000
# max        279.000000
# Name: non_diploma_credential_cnt, dtype: float64
# Nullcount: 33478.000000

# %% [markdown]
# This is skewed heavily to the right with many outliers.
#
# conclusions:
#
# We will normalize and standardize
#
# ### non_diploma_credential_pct

# %%
distbox(22,df)
# Out:
# Skewness: 4.939532
# Kurtosis: 35.948066
# count    39674.000000
# mean         1.742627
# std          4.063987
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          2.000000
# max         67.000000
# Name: non_diploma_credential_pct, dtype: float64
# Nullcount: 33478.000000

# %% [markdown]
# This is skewed heavily to the right with many outliers.
#
# conclusions:
#
# We will normalize and standardize
#
# ### still_enr_cnt

# %%
distbox(23,df)
# Out:
# Skewness: 10.042656
# Kurtosis: 169.593577
# count    39674.000000
# mean        11.299516
# std         40.766672
# min          0.000000
# 25%          0.000000
# 50%          2.000000
# 75%          5.000000
# max       1381.000000
# Name: still_enr_cnt, dtype: float64
# Nullcount: 33478.000000

# %% [markdown]
# This is skewed heavily to the right with many outliers.
#
# conclusions:
#
# We will normalize and standardize
#
# ### still_enr_pct

# %%
distbox(24,df)
# Out:
# Skewness: 4.453085
# Kurtosis: 31.428664
# count    39674.000000
# mean         5.190704
# std          8.832710
# min          0.000000
# 25%          0.000000
# 50%          2.000000
# 75%          6.000000
# max        100.000000
# Name: still_enr_pct, dtype: float64
# Nullcount: 33478.000000

# %% [markdown]
# This is skewed heavily to the right with many outliers.
#
# conclusions:
#
# We will normalize and standardize
#
# ### ged_cnt

# %%
distbox(25,df)
# Out:
# Skewness: 7.733184
# Kurtosis: 83.963713
# count    39674.000000
# mean         1.377577
# std          4.949389
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max         97.000000
# Name: ged_cnt, dtype: float64
# Nullcount: 33478.000000

# %% [markdown]
# This is skewed heavily to the right with many outliers.
#
# conclusions:
#
# We will normalize and standardize
#
# ### ged_pct

# %%
distbox(26,df)
# Out:
# Skewness: 9.425612
# Kurtosis: 171.746167
# count    39674.000000
# mean         0.612693
# std          1.985445
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         67.000000
# Name: ged_pct, dtype: float64
# Nullcount: 33478.000000

# %% [markdown]
# This is skewed heavily to the right with many outliers.
#
# conclusions:
#
# We will normalize and standardize

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### Groups represented data

# %%
#how many times does the subgroup show up in the datset. lower values = places without students in the category
subgroup_names = df.dropna().subgroup_name
#subgroup_names_counts.index

sns.set(rc={'figure.figsize':(24,10)})
sns.countplot(subgroup_names)
plt.xticks(rotation=-40 , rotation_mode='anchor',ha="left");

# %% [markdown]
# conclusions:
#
# When we drop out null columns, we have several classes that are significantly sparser than others we will combine:
# [Migrant, Not migrant, Foster Care, not in foster care, parent in armed forces, parent not in armed forces]
#
# ### Dropout Percent by Subgroup

# %%
sds = df.groupby(['subgroup_name'])['dropout_pct'].agg('sum')
sds.plot(kind='bar', title='Dropout Percent by Subgroup', ylabel= 'Dropout Percent', figsize=(20,10),);
plt.xticks(rotation=315 , rotation_mode='anchor',ha="left");

# %% [markdown]
# It looks like subgroups will be able to split dropout percentages into high/low splits very well. We expect this to be prominent in the models.
#
# ### Dropout Percent by County

# %%
cds = df[df.subgroup_code <= 1].groupby(df['county_name'])['dropout_pct'].agg('sum')
cds.plot(kind='bar', title='dropout_pct by county', ylabel='dropout_pct', figsize=(20,10));

# %% [markdown]
# There is a nontrivial range in these values. We expect it to be relatively highly “predictive” of the response variable.
#
# ### Correlation Analysis
#
# Analyses of non-categorical co-linearity

# %% [markdown]
# #### cnt data

# %%
dfn = df[['enroll_cnt','grad_cnt','local_cnt','reg_cnt','reg_cnt','reg_adv_cnt','non_diploma_credential_cnt','still_enr_cnt',
          'ged_cnt','dropout_cnt','dropout_pct']]

plt.figure(figsize=(14,10))
sns.heatmap(dfn.corr(),cmap='coolwarm',annot=False);
plt.xticks(rotation=40 , rotation_mode='anchor',ha="right");

# %% [markdown]
# None of these univariate features seem to be correlated with our target variable. This isn't entirely surprising, as we are comparing the counts to the percentages. Let us see if it improves below.
# #### pct data

# %%
dfn = df[pct_columns]

plt.figure(figsize=(14,10))
sns.heatmap(dfn.corr(),cmap='coolwarm',annot=False);
plt.xticks(rotation=40 , rotation_mode='anchor',ha="right");

# %% [markdown]
# We have a range of weak to negative correlations to our response variable, which is a surprise. The strongest features seem to be the still enrolled and local variables. That doesn't make a whole lot of sense, unless resources are being redistributed from students that dropped out to the rest of the students. We'll assume this isn't very predictive.
#
# The strongest *absolute* predictor here is grad_pct. It makes sense that the graduation percentage and dropout percentage are inversely correlated. We expect this feature to be highly predictive.

# %% [markdown]
# # Data Preparation
#
# We will now prepare the data for modeling, incorporating all of our exploratory findings.

# %%
data_prep = df.copy()

# %% [markdown]
# ## Create TARGET Categorical Indicators
#
# 1) As the first step of your Data Preparation work, you MUST create a new categorical indicator variable
# derived from the content of the dropout_pct attribute using the approach described above. Using the
# results of your EDA, create a new indicator variable named “dropout_pct_level” having the three
# possible categorizations described above (i.e., “low”, “medium”, and “high”). Ensure that an appropriate “dropout_pct_level” value is calculated for every observation contained within the data set.
#
# This new indicator variable (which you will need to create) will be comprised of three possible values:
# 1. “low”: indicates that the percentage of dropouts for a given school district / student subgrouping is
# less than ½ of the median percentage of all dropouts (i.e., across all school district / student
# subgroupings);
# 2. “medium”: indicates that the percentage of dropouts for a given school district / student
# subgrouping  is between 0.5 * the median percentage of all dropouts (i.e., across all school district /
# student subgroupings) and 1.5 * the median percentage of dropouts (i.e., across all school district /
# student subgroupings), i.e., (0.5 * median percentage) < percentage of dropouts for a given school
# district <= (1.5 * median percentage)
# 3. “high”: indicates that the percentage of dropouts for a given school district / student subgrouping
# exceeds 1.5 * the median percentage of all dropouts (i.e., across all school district / student
# subgroupings).
# As such, your machine learning models should be designed for purposes of predicting which of the three
# required new indicator values is most likely to apply to a given observation.

# %%
data_prep['dropout_pct'].median()
# Out:
# 5.0

# %%
data_prep['dropout_pct_level'] = 'medium'#create a categorization column, and set all values to medium
data_prep.loc[data_prep['dropout_pct'] > (1.5 * data_prep['dropout_pct'].median()), 'dropout_pct_level'] = 'high'#set all values greater than 1.5 * median to high
data_prep.loc[data_prep['dropout_pct'] < (.5 * data_prep['dropout_pct'].median()), 'dropout_pct_level'] = 'low'#set all values greater than .5 * median to low
data_prep['dropout_pct_level'].value_counts()

# %%
#sanity checks

scheck = data_prep.loc[data_prep['dropout_pct_level'] == 'high', ['dropout_pct_level','dropout_pct']]
print(scheck.iloc [0:2] )
scheck = data_prep.loc[data_prep['dropout_pct_level'] == 'medium', ['dropout_pct_level','dropout_pct']]
print(scheck.iloc [0:16] )
scheck = data_prep.loc[data_prep['dropout_pct_level'] == 'low', ['dropout_pct_level','dropout_pct']]
print(scheck.iloc [0:2] )
del scheck
# Out:
#   dropout_pct_level  dropout_pct
# 0              high         22.0
# 1              high         20.0
#    dropout_pct_level  dropout_pct
# 3             medium          NaN
# 8             medium          NaN
# 13            medium          NaN
# 16            medium          NaN
# 17            medium          NaN
# 20            medium          NaN
# 21            medium          NaN
# 25            medium          NaN
# 30            medium          NaN
# 38            medium          NaN
# 39            medium          NaN
# 42            medium          NaN
# 43            medium          NaN
# 47            medium          NaN
# 51            medium          7.0
# 52            medium          NaN
#    dropout_pct_level  dropout_pct
# 35               low          0.0
# 57               low          0.0

# %% [markdown]
# It looks like our categories were assigned appropriately, though we have many null values in our medium set. We will drop the rows missing significant amounts of data now, as well as the columns indicated during our

# %% [markdown]
# ## Dropping Columns & Rows

# %%
#drop columns identified in EDA and reg_cnt/reg_pct which would leak information to the model
data_prep = data_prep.drop(['report_school_year','aggregation_type','aggregation_index','subgroup_code', 'nrc_code', 'county_code','subgroup_code','dropout_pct','dropout_cnt'], axis = 1)

# dropping rows
#data_prep.dropna(subset=['dropout_cnt'], inplace=True)

#sanity check
data_prep.shape
# Out:
# (73152, 22)

# %%
#sanity check
data_prep.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>aggregation_name</th>
#       <th>nrc_desc</th>
#       <th>county_name</th>
#       <th>nyc_ind</th>
#       <th>membership_desc</th>
#       <th>subgroup_name</th>
#       <th>enroll_cnt</th>
#       <th>grad_cnt</th>
#       <th>grad_pct</th>
#       <th>local_cnt</th>
#       <th>local_pct</th>
#       <th>reg_cnt</th>
#       <th>reg_pct</th>
#       <th>reg_adv_cnt</th>
#       <th>reg_adv_pct</th>
#       <th>non_diploma_credential_cnt</th>
#       <th>non_diploma_credential_pct</th>
#       <th>still_enr_cnt</th>
#       <th>still_enr_pct</th>
#       <th>ged_cnt</th>
#       <th>ged_pct</th>
#       <th>dropout_pct_level</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ALBANY CITY SCHOOL DISTRICT</td>
#       <td>Urban-Suburban High Needs</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>All Students</td>
#       <td>658.0</td>
#       <td>464.0</td>
#       <td>71.0</td>
#       <td>63.0</td>
#       <td>10.0</td>
#       <td>310.0</td>
#       <td>47.0</td>
#       <td>91.0</td>
#       <td>14.0</td>
#       <td>16.0</td>
#       <td>2.0</td>
#       <td>30.0</td>
#       <td>5.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>high</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ALBANY CITY SCHOOL DISTRICT</td>
#       <td>Urban-Suburban High Needs</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>Female</td>
#       <td>324.0</td>
#       <td>246.0</td>
#       <td>76.0</td>
#       <td>30.0</td>
#       <td>9.0</td>
#       <td>169.0</td>
#       <td>52.0</td>
#       <td>47.0</td>
#       <td>15.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>11.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>high</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ALBANY CITY SCHOOL DISTRICT</td>
#       <td>Urban-Suburban High Needs</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>Male</td>
#       <td>334.0</td>
#       <td>218.0</td>
#       <td>65.0</td>
#       <td>33.0</td>
#       <td>10.0</td>
#       <td>141.0</td>
#       <td>42.0</td>
#       <td>44.0</td>
#       <td>13.0</td>
#       <td>14.0</td>
#       <td>4.0</td>
#       <td>19.0</td>
#       <td>6.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>high</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ALBANY CITY SCHOOL DISTRICT</td>
#       <td>Urban-Suburban High Needs</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>American Indian/Alaska Native</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>medium</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ALBANY CITY SCHOOL DISTRICT</td>
#       <td>Urban-Suburban High Needs</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>Black</td>
#       <td>367.0</td>
#       <td>248.0</td>
#       <td>68.0</td>
#       <td>42.0</td>
#       <td>11.0</td>
#       <td>183.0</td>
#       <td>50.0</td>
#       <td>23.0</td>
#       <td>6.0</td>
#       <td>10.0</td>
#       <td>3.0</td>
#       <td>18.0</td>
#       <td>5.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>high</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Sparse Classes
# We will now mutate our categorical variables to handle sparse classes

# %% [markdown]
# ### aggregation_name
#
# The first approach we will try will be feature hashing to squash cardinality. We choose 100 columns to reduce the chance of collisions while still reducing cardinality from traditional 1-hot encoding.

# %%
from sklearn.feature_extraction import FeatureHasher
num = 100 

aggregation_name = data_prep['aggregation_name']
hasher = FeatureHasher(n_features=num, input_type ='string') 
aggregation_name_hashed = hasher.fit_transform(aggregation_name)
column_names = [f'agg_hash_{x}'for x in range(num)]

aggregation_name_hashed_frame = pd.DataFrame(aggregation_name_hashed.todense(),columns=column_names)

print(aggregation_name_hashed_frame.shape)
aggregation_name_hashed_frame.head()
# Out:
# (73152, 100)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>agg_hash_0</th>
#       <th>agg_hash_1</th>
#       <th>agg_hash_2</th>
#       <th>agg_hash_3</th>
#       <th>agg_hash_4</th>
#       <th>agg_hash_5</th>
#       <th>agg_hash_6</th>
#       <th>agg_hash_7</th>
#       <th>agg_hash_8</th>
#       <th>agg_hash_9</th>
#       <th>agg_hash_10</th>
#       <th>agg_hash_11</th>
#       <th>agg_hash_12</th>
#       <th>agg_hash_13</th>
#       <th>agg_hash_14</th>
#       <th>agg_hash_15</th>
#       <th>agg_hash_16</th>
#       <th>agg_hash_17</th>
#       <th>agg_hash_18</th>
#       <th>agg_hash_19</th>
#       <th>agg_hash_20</th>
#       <th>agg_hash_21</th>
#       <th>agg_hash_22</th>
#       <th>agg_hash_23</th>
#       <th>agg_hash_24</th>
#       <th>agg_hash_25</th>
#       <th>agg_hash_26</th>
#       <th>agg_hash_27</th>
#       <th>agg_hash_28</th>
#       <th>agg_hash_29</th>
#       <th>agg_hash_30</th>
#       <th>agg_hash_31</th>
#       <th>agg_hash_32</th>
#       <th>agg_hash_33</th>
#       <th>agg_hash_34</th>
#       <th>agg_hash_35</th>
#       <th>agg_hash_36</th>
#       <th>agg_hash_37</th>
#       <th>agg_hash_38</th>
#       <th>agg_hash_39</th>
#       <th>agg_hash_40</th>
#       <th>agg_hash_41</th>
#       <th>agg_hash_42</th>
#       <th>agg_hash_43</th>
#       <th>agg_hash_44</th>
#       <th>agg_hash_45</th>
#       <th>agg_hash_46</th>
#       <th>agg_hash_47</th>
#       <th>agg_hash_48</th>
#       <th>agg_hash_49</th>
#       <th>agg_hash_50</th>
#       <th>agg_hash_51</th>
#       <th>agg_hash_52</th>
#       <th>agg_hash_53</th>
#       <th>agg_hash_54</th>
#       <th>agg_hash_55</th>
#       <th>agg_hash_56</th>
#       <th>agg_hash_57</th>
#       <th>agg_hash_58</th>
#       <th>agg_hash_59</th>
#       <th>agg_hash_60</th>
#       <th>agg_hash_61</th>
#       <th>agg_hash_62</th>
#       <th>agg_hash_63</th>
#       <th>agg_hash_64</th>
#       <th>agg_hash_65</th>
#       <th>agg_hash_66</th>
#       <th>agg_hash_67</th>
#       <th>agg_hash_68</th>
#       <th>agg_hash_69</th>
#       <th>agg_hash_70</th>
#       <th>agg_hash_71</th>
#       <th>agg_hash_72</th>
#       <th>agg_hash_73</th>
#       <th>agg_hash_74</th>
#       <th>agg_hash_75</th>
#       <th>agg_hash_76</th>
#       <th>agg_hash_77</th>
#       <th>agg_hash_78</th>
#       <th>agg_hash_79</th>
#       <th>agg_hash_80</th>
#       <th>agg_hash_81</th>
#       <th>agg_hash_82</th>
#       <th>agg_hash_83</th>
#       <th>agg_hash_84</th>
#       <th>agg_hash_85</th>
#       <th>agg_hash_86</th>
#       <th>agg_hash_87</th>
#       <th>agg_hash_88</th>
#       <th>agg_hash_89</th>
#       <th>agg_hash_90</th>
#       <th>agg_hash_91</th>
#       <th>agg_hash_92</th>
#       <th>agg_hash_93</th>
#       <th>agg_hash_94</th>
#       <th>agg_hash_95</th>
#       <th>agg_hash_96</th>
#       <th>agg_hash_97</th>
#       <th>agg_hash_98</th>
#       <th>agg_hash_99</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-2.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-8.0</td>
#       <td>-1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>-2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-2.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-8.0</td>
#       <td>-1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>-2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-2.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>

# %% [markdown]
# We have condensed the aggregation names into a 100 column space, a huge decrease from what we would have by utilizing 1 hot encoding. It is no longer human-readable, but we believe the tradeoff is worthwhile to leverage in feature selection for the model. We will now replace the column in our dataframe with the hashed dataframe.

# %%
#replace aggregation name with hashed columns
data_prep.drop(['aggregation_name'], axis=1, inplace=True)
data_prep = pd.concat([data_prep, aggregation_name_hashed_frame], axis=1 )
data_prep.dropna(subset=['ged_cnt'], inplace=True)#droping rows here instead of earlier to prevent problems with concat function
del aggregation_name_hashed_frame
data_prep.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>nrc_desc</th>
#       <th>county_name</th>
#       <th>nyc_ind</th>
#       <th>membership_desc</th>
#       <th>subgroup_name</th>
#       <th>enroll_cnt</th>
#       <th>grad_cnt</th>
#       <th>grad_pct</th>
#       <th>local_cnt</th>
#       <th>local_pct</th>
#       <th>reg_cnt</th>
#       <th>reg_pct</th>
#       <th>reg_adv_cnt</th>
#       <th>reg_adv_pct</th>
#       <th>non_diploma_credential_cnt</th>
#       <th>non_diploma_credential_pct</th>
#       <th>still_enr_cnt</th>
#       <th>still_enr_pct</th>
#       <th>ged_cnt</th>
#       <th>ged_pct</th>
#       <th>dropout_pct_level</th>
#       <th>agg_hash_0</th>
#       <th>agg_hash_1</th>
#       <th>agg_hash_2</th>
#       <th>agg_hash_3</th>
#       <th>agg_hash_4</th>
#       <th>agg_hash_5</th>
#       <th>agg_hash_6</th>
#       <th>agg_hash_7</th>
#       <th>agg_hash_8</th>
#       <th>agg_hash_9</th>
#       <th>agg_hash_10</th>
#       <th>agg_hash_11</th>
#       <th>agg_hash_12</th>
#       <th>agg_hash_13</th>
#       <th>agg_hash_14</th>
#       <th>agg_hash_15</th>
#       <th>agg_hash_16</th>
#       <th>agg_hash_17</th>
#       <th>agg_hash_18</th>
#       <th>agg_hash_19</th>
#       <th>agg_hash_20</th>
#       <th>agg_hash_21</th>
#       <th>agg_hash_22</th>
#       <th>agg_hash_23</th>
#       <th>agg_hash_24</th>
#       <th>agg_hash_25</th>
#       <th>agg_hash_26</th>
#       <th>agg_hash_27</th>
#       <th>agg_hash_28</th>
#       <th>agg_hash_29</th>
#       <th>agg_hash_30</th>
#       <th>agg_hash_31</th>
#       <th>agg_hash_32</th>
#       <th>agg_hash_33</th>
#       <th>agg_hash_34</th>
#       <th>agg_hash_35</th>
#       <th>agg_hash_36</th>
#       <th>agg_hash_37</th>
#       <th>agg_hash_38</th>
#       <th>agg_hash_39</th>
#       <th>agg_hash_40</th>
#       <th>agg_hash_41</th>
#       <th>agg_hash_42</th>
#       <th>agg_hash_43</th>
#       <th>agg_hash_44</th>
#       <th>agg_hash_45</th>
#       <th>agg_hash_46</th>
#       <th>agg_hash_47</th>
#       <th>agg_hash_48</th>
#       <th>agg_hash_49</th>
#       <th>agg_hash_50</th>
#       <th>agg_hash_51</th>
#       <th>agg_hash_52</th>
#       <th>agg_hash_53</th>
#       <th>agg_hash_54</th>
#       <th>agg_hash_55</th>
#       <th>agg_hash_56</th>
#       <th>agg_hash_57</th>
#       <th>agg_hash_58</th>
#       <th>agg_hash_59</th>
#       <th>agg_hash_60</th>
#       <th>agg_hash_61</th>
#       <th>agg_hash_62</th>
#       <th>agg_hash_63</th>
#       <th>agg_hash_64</th>
#       <th>agg_hash_65</th>
#       <th>agg_hash_66</th>
#       <th>agg_hash_67</th>
#       <th>agg_hash_68</th>
#       <th>agg_hash_69</th>
#       <th>agg_hash_70</th>
#       <th>agg_hash_71</th>
#       <th>agg_hash_72</th>
#       <th>agg_hash_73</th>
#       <th>agg_hash_74</th>
#       <th>agg_hash_75</th>
#       <th>agg_hash_76</th>
#       <th>agg_hash_77</th>
#       <th>agg_hash_78</th>
#       <th>agg_hash_79</th>
#       <th>agg_hash_80</th>
#       <th>agg_hash_81</th>
#       <th>agg_hash_82</th>
#       <th>agg_hash_83</th>
#       <th>agg_hash_84</th>
#       <th>agg_hash_85</th>
#       <th>agg_hash_86</th>
#       <th>agg_hash_87</th>
#       <th>agg_hash_88</th>
#       <th>agg_hash_89</th>
#       <th>agg_hash_90</th>
#       <th>agg_hash_91</th>
#       <th>agg_hash_92</th>
#       <th>agg_hash_93</th>
#       <th>agg_hash_94</th>
#       <th>agg_hash_95</th>
#       <th>agg_hash_96</th>
#       <th>agg_hash_97</th>
#       <th>agg_hash_98</th>
#       <th>agg_hash_99</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Urban-Suburban High Needs</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>All Students</td>
#       <td>658.0</td>
#       <td>464.0</td>
#       <td>71.0</td>
#       <td>63.0</td>
#       <td>10.0</td>
#       <td>310.0</td>
#       <td>47.0</td>
#       <td>91.0</td>
#       <td>14.0</td>
#       <td>16.0</td>
#       <td>2.0</td>
#       <td>30.0</td>
#       <td>5.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>high</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-2.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-8.0</td>
#       <td>-1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>-2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Urban-Suburban High Needs</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>Female</td>
#       <td>324.0</td>
#       <td>246.0</td>
#       <td>76.0</td>
#       <td>30.0</td>
#       <td>9.0</td>
#       <td>169.0</td>
#       <td>52.0</td>
#       <td>47.0</td>
#       <td>15.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>11.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>high</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-2.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <

# %%
#null visualization
sns.set(rc={'figure.figsize':(15,5)})
sns.heatmap(data_prep.isnull(), cmap='viridis');

# %% [markdown]
# ### county_name
# There are fewer values for county name, so we will explore a simpler sparse class combination
# `sum(countyname.value_counts(normalize=True)< .01)` = 19
# there are 19 category names that represent less than 1 percent of our data. We will combine them.
#
# code referenced: https://www.codegrepper.com/code-examples/python/combining+sparse+class

# %%
#move data into object for safe mutation
county = data_prep['county_name'].copy()

#create mask to identify subgroups <x percent of data
countylist = county.value_counts(normalize=True) < .01
countylist = countylist[countylist.values].index
mask = county.isin(countylist)

#use mask to update target values
county[mask] = 'OTHER'

#visualize outcome
print(county.value_counts().shape)
sns.countplot(county);
plt.xticks(rotation=40 , rotation_mode='anchor',ha="right");
# Out:
# (36,)

# %% [markdown]
# Conclusion:
#
# Using our updated county array, we will reduce 58 variables to 36 columns with 1 hot encoding. This is not as good as the 30 we would get with hashing but without the downsides ("collisions" and reduced explain-ability) that we would receive for such a small reduction.

# %%
#replace county name with data reduced columns
data_prep['county_name'] = county
del county
data_prep.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>nrc_desc</th>
#       <th>county_name</th>
#       <th>nyc_ind</th>
#       <th>membership_desc</th>
#       <th>subgroup_name</th>
#       <th>enroll_cnt</th>
#       <th>grad_cnt</th>
#       <th>grad_pct</th>
#       <th>local_cnt</th>
#       <th>local_pct</th>
#       <th>reg_cnt</th>
#       <th>reg_pct</th>
#       <th>reg_adv_cnt</th>
#       <th>reg_adv_pct</th>
#       <th>non_diploma_credential_cnt</th>
#       <th>non_diploma_credential_pct</th>
#       <th>still_enr_cnt</th>
#       <th>still_enr_pct</th>
#       <th>ged_cnt</th>
#       <th>ged_pct</th>
#       <th>dropout_pct_level</th>
#       <th>agg_hash_0</th>
#       <th>agg_hash_1</th>
#       <th>agg_hash_2</th>
#       <th>agg_hash_3</th>
#       <th>agg_hash_4</th>
#       <th>agg_hash_5</th>
#       <th>agg_hash_6</th>
#       <th>agg_hash_7</th>
#       <th>agg_hash_8</th>
#       <th>agg_hash_9</th>
#       <th>agg_hash_10</th>
#       <th>agg_hash_11</th>
#       <th>agg_hash_12</th>
#       <th>agg_hash_13</th>
#       <th>agg_hash_14</th>
#       <th>agg_hash_15</th>
#       <th>agg_hash_16</th>
#       <th>agg_hash_17</th>
#       <th>agg_hash_18</th>
#       <th>agg_hash_19</th>
#       <th>agg_hash_20</th>
#       <th>agg_hash_21</th>
#       <th>agg_hash_22</th>
#       <th>agg_hash_23</th>
#       <th>agg_hash_24</th>
#       <th>agg_hash_25</th>
#       <th>agg_hash_26</th>
#       <th>agg_hash_27</th>
#       <th>agg_hash_28</th>
#       <th>agg_hash_29</th>
#       <th>agg_hash_30</th>
#       <th>agg_hash_31</th>
#       <th>agg_hash_32</th>
#       <th>agg_hash_33</th>
#       <th>agg_hash_34</th>
#       <th>agg_hash_35</th>
#       <th>agg_hash_36</th>
#       <th>agg_hash_37</th>
#       <th>agg_hash_38</th>
#       <th>agg_hash_39</th>
#       <th>agg_hash_40</th>
#       <th>agg_hash_41</th>
#       <th>agg_hash_42</th>
#       <th>agg_hash_43</th>
#       <th>agg_hash_44</th>
#       <th>agg_hash_45</th>
#       <th>agg_hash_46</th>
#       <th>agg_hash_47</th>
#       <th>agg_hash_48</th>
#       <th>agg_hash_49</th>
#       <th>agg_hash_50</th>
#       <th>agg_hash_51</th>
#       <th>agg_hash_52</th>
#       <th>agg_hash_53</th>
#       <th>agg_hash_54</th>
#       <th>agg_hash_55</th>
#       <th>agg_hash_56</th>
#       <th>agg_hash_57</th>
#       <th>agg_hash_58</th>
#       <th>agg_hash_59</th>
#       <th>agg_hash_60</th>
#       <th>agg_hash_61</th>
#       <th>agg_hash_62</th>
#       <th>agg_hash_63</th>
#       <th>agg_hash_64</th>
#       <th>agg_hash_65</th>
#       <th>agg_hash_66</th>
#       <th>agg_hash_67</th>
#       <th>agg_hash_68</th>
#       <th>agg_hash_69</th>
#       <th>agg_hash_70</th>
#       <th>agg_hash_71</th>
#       <th>agg_hash_72</th>
#       <th>agg_hash_73</th>
#       <th>agg_hash_74</th>
#       <th>agg_hash_75</th>
#       <th>agg_hash_76</th>
#       <th>agg_hash_77</th>
#       <th>agg_hash_78</th>
#       <th>agg_hash_79</th>
#       <th>agg_hash_80</th>
#       <th>agg_hash_81</th>
#       <th>agg_hash_82</th>
#       <th>agg_hash_83</th>
#       <th>agg_hash_84</th>
#       <th>agg_hash_85</th>
#       <th>agg_hash_86</th>
#       <th>agg_hash_87</th>
#       <th>agg_hash_88</th>
#       <th>agg_hash_89</th>
#       <th>agg_hash_90</th>
#       <th>agg_hash_91</th>
#       <th>agg_hash_92</th>
#       <th>agg_hash_93</th>
#       <th>agg_hash_94</th>
#       <th>agg_hash_95</th>
#       <th>agg_hash_96</th>
#       <th>agg_hash_97</th>
#       <th>agg_hash_98</th>
#       <th>agg_hash_99</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Urban-Suburban High Needs</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>All Students</td>
#       <td>658.0</td>
#       <td>464.0</td>
#       <td>71.0</td>
#       <td>63.0</td>
#       <td>10.0</td>
#       <td>310.0</td>
#       <td>47.0</td>
#       <td>91.0</td>
#       <td>14.0</td>
#       <td>16.0</td>
#       <td>2.0</td>
#       <td>30.0</td>
#       <td>5.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>high</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-2.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-8.0</td>
#       <td>-1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>-2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Urban-Suburban High Needs</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>Female</td>
#       <td>324.0</td>
#       <td>246.0</td>
#       <td>76.0</td>
#       <td>30.0</td>
#       <td>9.0</td>
#       <td>169.0</td>
#       <td>52.0</td>
#       <td>47.0</td>
#       <td>15.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>11.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>high</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-2.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <

# %% [markdown]
# ### subgroup_name
# We will combine any subgroup comprising less than 2 percent of records into a single group

# %%
#move data into object for safe mutation
subgroup_name = data_prep['subgroup_name'].copy()

#create mask to identify subgroups <x percent of data
subgroup_drops = subgroup_name.value_counts(normalize=True)<.02
subgroup_drops = subgroup_drops[subgroup_drops.values].index
mask = subgroup_name.isin(subgroup_drops)

#use mask to update target values
subgroup_name[mask]='Other'

#visualize outcome
subgroup_counts = subgroup_name.value_counts(normalize=True)
sns.barplot(subgroup_counts.index,subgroup_counts.values*100);
plt.xticks(rotation=40 , rotation_mode='anchor',ha="right");

# %%
#replacing subgroup_name
data_prep['subgroup_name'] = subgroup_name
del subgroup_name
data_prep.subgroup_name.value_counts()#sanity check

# %% [markdown]
# ### nrc_desc
# To even our classes we will combine the following into an "other" class. ['Buffalo  Rochester  Yonkers  Syracuse ', 'NYC', 'Urban-Suburban High Needs']
#
# nyc_id will continue to provide information about NYC membership so we will not lose all distinct data from the NYC area.

# %%
#move data into object for safe mutation
nrc_desc = data_prep['nrc_desc'].copy()

#create mask to identify subgroups
nrc_desc_combine = ['Buffalo  Rochester  Yonkers  Syracuse','NYC','Urban-Suburban High Needs']

mask = nrc_desc.isin(nrc_desc_combine)

#use mask to update target values
nrc_desc[mask]='Other'

#visualize outcome
sns.countplot(nrc_desc);
plt.xticks(rotation=40 , rotation_mode='anchor',ha="right");

# %%
#adding transformed nrc_desc back to data_prep
data_prep['nrc_desc'] = nrc_desc
del nrc_desc
data_prep.nrc_desc.value_counts()#sanity check

# %%
data_prep.head(2)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>nrc_desc</th>
#       <th>county_name</th>
#       <th>nyc_ind</th>
#       <th>membership_desc</th>
#       <th>subgroup_name</th>
#       <th>enroll_cnt</th>
#       <th>grad_cnt</th>
#       <th>grad_pct</th>
#       <th>local_cnt</th>
#       <th>local_pct</th>
#       <th>reg_cnt</th>
#       <th>reg_pct</th>
#       <th>reg_adv_cnt</th>
#       <th>reg_adv_pct</th>
#       <th>non_diploma_credential_cnt</th>
#       <th>non_diploma_credential_pct</th>
#       <th>still_enr_cnt</th>
#       <th>still_enr_pct</th>
#       <th>ged_cnt</th>
#       <th>ged_pct</th>
#       <th>dropout_pct_level</th>
#       <th>agg_hash_0</th>
#       <th>agg_hash_1</th>
#       <th>agg_hash_2</th>
#       <th>agg_hash_3</th>
#       <th>agg_hash_4</th>
#       <th>agg_hash_5</th>
#       <th>agg_hash_6</th>
#       <th>agg_hash_7</th>
#       <th>agg_hash_8</th>
#       <th>agg_hash_9</th>
#       <th>agg_hash_10</th>
#       <th>agg_hash_11</th>
#       <th>agg_hash_12</th>
#       <th>agg_hash_13</th>
#       <th>agg_hash_14</th>
#       <th>agg_hash_15</th>
#       <th>agg_hash_16</th>
#       <th>agg_hash_17</th>
#       <th>agg_hash_18</th>
#       <th>agg_hash_19</th>
#       <th>agg_hash_20</th>
#       <th>agg_hash_21</th>
#       <th>agg_hash_22</th>
#       <th>agg_hash_23</th>
#       <th>agg_hash_24</th>
#       <th>agg_hash_25</th>
#       <th>agg_hash_26</th>
#       <th>agg_hash_27</th>
#       <th>agg_hash_28</th>
#       <th>agg_hash_29</th>
#       <th>agg_hash_30</th>
#       <th>agg_hash_31</th>
#       <th>agg_hash_32</th>
#       <th>agg_hash_33</th>
#       <th>agg_hash_34</th>
#       <th>agg_hash_35</th>
#       <th>agg_hash_36</th>
#       <th>agg_hash_37</th>
#       <th>agg_hash_38</th>
#       <th>agg_hash_39</th>
#       <th>agg_hash_40</th>
#       <th>agg_hash_41</th>
#       <th>agg_hash_42</th>
#       <th>agg_hash_43</th>
#       <th>agg_hash_44</th>
#       <th>agg_hash_45</th>
#       <th>agg_hash_46</th>
#       <th>agg_hash_47</th>
#       <th>agg_hash_48</th>
#       <th>agg_hash_49</th>
#       <th>agg_hash_50</th>
#       <th>agg_hash_51</th>
#       <th>agg_hash_52</th>
#       <th>agg_hash_53</th>
#       <th>agg_hash_54</th>
#       <th>agg_hash_55</th>
#       <th>agg_hash_56</th>
#       <th>agg_hash_57</th>
#       <th>agg_hash_58</th>
#       <th>agg_hash_59</th>
#       <th>agg_hash_60</th>
#       <th>agg_hash_61</th>
#       <th>agg_hash_62</th>
#       <th>agg_hash_63</th>
#       <th>agg_hash_64</th>
#       <th>agg_hash_65</th>
#       <th>agg_hash_66</th>
#       <th>agg_hash_67</th>
#       <th>agg_hash_68</th>
#       <th>agg_hash_69</th>
#       <th>agg_hash_70</th>
#       <th>agg_hash_71</th>
#       <th>agg_hash_72</th>
#       <th>agg_hash_73</th>
#       <th>agg_hash_74</th>
#       <th>agg_hash_75</th>
#       <th>agg_hash_76</th>
#       <th>agg_hash_77</th>
#       <th>agg_hash_78</th>
#       <th>agg_hash_79</th>
#       <th>agg_hash_80</th>
#       <th>agg_hash_81</th>
#       <th>agg_hash_82</th>
#       <th>agg_hash_83</th>
#       <th>agg_hash_84</th>
#       <th>agg_hash_85</th>
#       <th>agg_hash_86</th>
#       <th>agg_hash_87</th>
#       <th>agg_hash_88</th>
#       <th>agg_hash_89</th>
#       <th>agg_hash_90</th>
#       <th>agg_hash_91</th>
#       <th>agg_hash_92</th>
#       <th>agg_hash_93</th>
#       <th>agg_hash_94</th>
#       <th>agg_hash_95</th>
#       <th>agg_hash_96</th>
#       <th>agg_hash_97</th>
#       <th>agg_hash_98</th>
#       <th>agg_hash_99</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Other</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>All Students</td>
#       <td>658.0</td>
#       <td>464.0</td>
#       <td>71.0</td>
#       <td>63.0</td>
#       <td>10.0</td>
#       <td>310.0</td>
#       <td>47.0</td>
#       <td>91.0</td>
#       <td>14.0</td>
#       <td>16.0</td>
#       <td>2.0</td>
#       <td>30.0</td>
#       <td>5.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>high</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-2.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-8.0</td>
#       <td>-1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>-2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Other</td>
#       <td>ALBANY</td>
#       <td>0</td>
#       <td>2013 Total Cohort - 6 Year Outcome</td>
#       <td>Female</td>
#       <td>324.0</td>
#       <td>246.0</td>
#       <td>76.0</td>
#       <td>30.0</td>
#       <td>9.0</td>
#       <td>169.0</td>
#       <td>52.0</td>
#       <td>47.0</td>
#       <td>15.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>11.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>high</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-2.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td

# %% [markdown]
# ## Standardize and Normalize Quantitative Data

# %%
from sklearn.preprocessing import power_transform as pt 

pct_columns = ['grad_pct','local_pct','reg_adv_pct','non_diploma_credential_pct','still_enr_pct','ged_pct','reg_pct']
cnt_columns = ['enroll_cnt','grad_cnt','local_cnt','reg_adv_cnt','non_diploma_credential_cnt','still_enr_cnt','ged_cnt','reg_cnt']

columns = cnt_columns + pct_columns
print(columns)

for column in columns:#iterate over identified columns
  a = data_prep[[column]]
  data_prep[column] = pt(a,method='yeo-johnson')#we are performing a yeo-johnson transformation because most of the features have negative or 0 values

data_prep[columns].head(2)#sanity check
# Out:
# ['enroll_cnt', 'grad_cnt', 'local_cnt', 'reg_adv_cnt', 'non_diploma_credential_cnt', 'still_enr_cnt', 'ged_cnt', 'reg_cnt', 'grad_pct', 'local_pct', 'reg_adv_pct', 'non_diploma_credential_pct', 'still_enr_pct', 'ged_pct', 'reg_pct']
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>enroll_cnt</th>
#       <th>grad_cnt</th>
#       <th>local_cnt</th>
#       <th>reg_adv_cnt</th>
#       <th>non_diploma_credential_cnt</th>
#       <th>still_enr_cnt</th>
#       <th>ged_cnt</th>
#       <th>reg_cnt</th>
#       <th>grad_pct</th>
#       <th>local_pct</th>
#       <th>reg_adv_pct</th>
#       <th>non_diploma_credential_pct</th>
#       <th>still_enr_pct</th>
#       <th>ged_pct</th>
#       <th>reg_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.556674</td>
#       <td>1.439241</td>
#       <td>1.795464</td>
#       <td>0.961980</td>
#       <td>1.836021</td>
#       <td>1.554668</td>
#       <td>-0.588644</td>
#       <td>1.619218</td>
#       <td>-1.203165</td>
#       <td>0.594673</td>
#       <td>-0.660607</td>
#       <td>1.105788</td>
#       <td>0.642314</td>
#       <td>-0.538319</td>
#       <td>0.240588</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.117188</td>
#       <td>1.017930</td>
#       <td>1.405988</td>
#       <td>0.573121</td>
#       <td>1.030762</td>
#       <td>1.139663</td>
#       <td>-0.588644</td>
#       <td>1.239676</td>
#       <td>-0.905171</td>
#       <td>0.499016</td>
#       <td>-0.607039</td>
#       <td>0.653716</td>
#       <td>0.286694</td>
#       <td>-0.538319</td>
#       <td>0.523544</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Dummying Categorical Data

# %%
#dummying county_name, membership_desc, subgroup_name, nrc_desc using the patsy library

formula = """C(subgroup_name)+ C(county_name)+C(membership_desc)+C(nrc_desc)"""
dum = dmatrix(formula, data_prep, return_type='dataframe').astype('int32')
dum.head(2)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Intercept</th>
#       <th>C(subgroup_name)[T.Asian/Pacific Islander]</th>
#       <th>C(subgroup_name)[T.Black]</th>
#       <th>C(subgroup_name)[T.Economically Disadvantaged]</th>
#       <th>C(subgroup_name)[T.English Language Learner]</th>
#       <th>C(subgroup_name)[T.Female]</th>
#       <th>C(subgroup_name)[T.General Education Students]</th>
#       <th>C(subgroup_name)[T.Hispanic]</th>
#       <th>C(subgroup_name)[T.Homeless]</th>
#       <th>C(subgroup_name)[T.Male]</th>
#       <th>C(subgroup_name)[T.Not Economically Disadvantaged]</th>
#       <th>C(subgroup_name)[T.Not English Language Learner]</th>
#       <th>C(subgroup_name)[T.Not Homeless]</th>
#       <th>C(subgroup_name)[T.Other]</th>
#       <th>C(subgroup_name)[T.Students with Disabilities]</th>
#       <th>C(subgroup_name)[T.White]</th>
#       <th>C(county_name)[T.ALLEGANY]</th>
#       <th>C(county_name)[T.BRONX]</th>
#       <th>C(county_name)[T.BROOME]</th>
#       <th>C(county_name)[T.CATTARAUGUS]</th>
#       <th>C(county_name)[T.CHAUTAUQUA]</th>
#       <th>C(county_name)[T.DELAWARE]</th>
#       <th>C(county_name)[T.DUTCHESS]</th>
#       <th>C(county_name)[T.ERIE]</th>
#       <th>C(county_name)[T.HERKIMER]</th>
#       <th>C(county_name)[T.JEFFERSON]</th>
#       <th>C(county_name)[T.KINGS]</th>
#       <th>C(county_name)[T.MADISON]</th>
#       <th>C(county_name)[T.MONROE]</th>
#       <th>C(county_name)[T.NASSAU]</th>
#       <th>C(county_name)[T.NEW YORK]</th>
#       <th>C(county_name)[T.NIAGARA]</th>
#       <th>C(county_name)[T.ONEIDA]</th>
#       <th>C(county_name)[T.ONONDAGA]</th>
#       <th>C(county_name)[T.ONTARIO]</th>
#       <th>C(county_name)[T.ORANGE]</th>
#       <th>C(county_name)[T.OSWEGO]</th>
#       <th>C(county_name)[T.OTHER]</th>
#       <th>C(county_name)[T.OTSEGO]</th>
#       <th>C(county_name)[T.QUEENS]</th>
#       <th>C(county_name)[T.RENSSELAER]</th>
#       <th>C(county_name)[T.ROCKLAND]</th>
#       <th>C(county_name)[T.SAINT LAWRENCE]</th>
#       <th>C(county_name)[T.SARATOGA]</th>
#       <th>C(county_name)[T.STEUBEN]</th>
#       <th>C(county_name)[T.SUFFOLK]</th>
#       <th>C(county_name)[T.SULLIVAN]</th>
#       <th>C(county_name)[T.ULSTER]</th>
#       <th>C(county_name)[T.WASHINGTON]</th>
#       <th>C(county_name)[T.WAYNE]</th>
#       <th>C(county_name)[T.WESTCHESTER]</th>
#       <th>C(membership_desc)[T.2013 Total Cohort - 6 Year Outcome - August 2019]</th>
#       <th>C(membership_desc)[T.2014 Total Cohort - 5 Year Outcome]</th>
#       <th>C(membership_desc)[T.2014 Total Cohort - 5 Year Outcome - August 2019]</th>
#       <th>C(membership_desc)[T.2015 Total Cohort - 4 Year Outcome]</th>
#       <th>C(membership_desc)[T.2015 Total Cohort - 4 Year Outcome - August 2019]</th>
#       <th>C(nrc_desc)[T.Low Needs]</th>
#       <th>C(nrc_desc)[T.Other]</th>
#       <th>C(nrc_desc)[T.Rural High Needs]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Now we will replace the categorical values with the dummied data

# %%
data_prep.drop(['subgroup_name','county_name','membership_desc','nrc_desc'], axis=1,inplace=True)
data_prep = pd.concat([data_prep, dum], axis=1, )
del dum
data_prep.head(2)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>nyc_ind</th>
#       <th>enroll_cnt</th>
#       <th>grad_cnt</th>
#       <th>grad_pct</th>
#       <th>local_cnt</th>
#       <th>local_pct</th>
#       <th>reg_cnt</th>
#       <th>reg_pct</th>
#       <th>reg_adv_cnt</th>
#       <th>reg_adv_pct</th>
#       <th>non_diploma_credential_cnt</th>
#       <th>non_diploma_credential_pct</th>
#       <th>still_enr_cnt</th>
#       <th>still_enr_pct</th>
#       <th>ged_cnt</th>
#       <th>ged_pct</th>
#       <th>dropout_pct_level</th>
#       <th>agg_hash_0</th>
#       <th>agg_hash_1</th>
#       <th>agg_hash_2</th>
#       <th>agg_hash_3</th>
#       <th>agg_hash_4</th>
#       <th>agg_hash_5</th>
#       <th>agg_hash_6</th>
#       <th>agg_hash_7</th>
#       <th>agg_hash_8</th>
#       <th>agg_hash_9</th>
#       <th>agg_hash_10</th>
#       <th>agg_hash_11</th>
#       <th>agg_hash_12</th>
#       <th>agg_hash_13</th>
#       <th>agg_hash_14</th>
#       <th>agg_hash_15</th>
#       <th>agg_hash_16</th>
#       <th>agg_hash_17</th>
#       <th>agg_hash_18</th>
#       <th>agg_hash_19</th>
#       <th>agg_hash_20</th>
#       <th>agg_hash_21</th>
#       <th>agg_hash_22</th>
#       <th>agg_hash_23</th>
#       <th>agg_hash_24</th>
#       <th>agg_hash_25</th>
#       <th>agg_hash_26</th>
#       <th>agg_hash_27</th>
#       <th>agg_hash_28</th>
#       <th>agg_hash_29</th>
#       <th>agg_hash_30</th>
#       <th>agg_hash_31</th>
#       <th>agg_hash_32</th>
#       <th>agg_hash_33</th>
#       <th>agg_hash_34</th>
#       <th>agg_hash_35</th>
#       <th>agg_hash_36</th>
#       <th>agg_hash_37</th>
#       <th>agg_hash_38</th>
#       <th>agg_hash_39</th>
#       <th>agg_hash_40</th>
#       <th>agg_hash_41</th>
#       <th>agg_hash_42</th>
#       <th>agg_hash_43</th>
#       <th>agg_hash_44</th>
#       <th>agg_hash_45</th>
#       <th>agg_hash_46</th>
#       <th>agg_hash_47</th>
#       <th>agg_hash_48</th>
#       <th>agg_hash_49</th>
#       <th>agg_hash_50</th>
#       <th>agg_hash_51</th>
#       <th>agg_hash_52</th>
#       <th>agg_hash_53</th>
#       <th>agg_hash_54</th>
#       <th>agg_hash_55</th>
#       <th>agg_hash_56</th>
#       <th>agg_hash_57</th>
#       <th>agg_hash_58</th>
#       <th>agg_hash_59</th>
#       <th>agg_hash_60</th>
#       <th>agg_hash_61</th>
#       <th>agg_hash_62</th>
#       <th>agg_hash_63</th>
#       <th>agg_hash_64</th>
#       <th>agg_hash_65</th>
#       <th>agg_hash_66</th>
#       <th>agg_hash_67</th>
#       <th>agg_hash_68</th>
#       <th>agg_hash_69</th>
#       <th>agg_hash_70</th>
#       <th>agg_hash_71</th>
#       <th>agg_hash_72</th>
#       <th>agg_hash_73</th>
#       <th>agg_hash_74</th>
#       <th>agg_hash_75</th>
#       <th>agg_hash_76</th>
#       <th>agg_hash_77</th>
#       <th>agg_hash_78</th>
#       <th>agg_hash_79</th>
#       <th>agg_hash_80</th>
#       <th>agg_hash_81</th>
#       <th>agg_hash_82</th>
#       <th>agg_hash_83</th>
#       <th>agg_hash_84</th>
#       <th>agg_hash_85</th>
#       <th>agg_hash_86</th>
#       <th>agg_hash_87</th>
#       <th>agg_hash_88</th>
#       <th>agg_hash_89</th>
#       <th>agg_hash_90</th>
#       <th>agg_hash_91</th>
#       <th>agg_hash_92</th>
#       <th>agg_hash_93</th>
#       <th>agg_hash_94</th>
#       <th>agg_hash_95</th>
#       <th>agg_hash_96</th>
#       <th>agg_hash_97</th>
#       <th>agg_hash_98</th>
#       <th>agg_hash_99</th>
#       <th>Intercept</th>
#       <th>C(subgroup_name)[T.Asian/Pacific Islander]</th>
#       <th>C(subgroup_name)[T.Black]</th>
#       <th>C(subgroup_name)[T.Economically Disadvantaged]</th>
#       <th>C(subgroup_name)[T.English Language Learner]</th>
#       <th>C(subgroup_name)[T.Female]</th>
#       <th>C(subgroup_name)[T.General Education Students]</th>
#       <th>C(subgroup_name)[T.Hispanic]</th>
#       <th>C(subgroup_name)[T.Homeless]</th>
#       <th>C(subgroup_name)[T.Male]</th>
#       <th>C(subgroup_name)[T.Not Economically Disadvantaged]</th>
#       <th>C(subgroup_name)[T.Not English Language Learner]</th>
#       <th>C(subgroup_name)[T.Not Homeless]</th>
#       <th>C(subgroup_name)[T.Other]</th>
#       <th>C(subgroup_name)[T.Students with Disabilities]</th>
#       <th>C(subgroup_name)[T.White]</th>
#       <th>C(county_name)[T.ALLEGANY]</th>
#       <th>C(county_name)[T.BRONX]</th>
#       <th>C(county_name)[T.BROOME]</th>
#       <th>C(county_name)[T.CATTARAUGUS]</th>
#       <th>C(county_name)[T.CHAUTAUQUA]</th>
#       <th>C(county_name)[T.DELAWARE]</th>
#       <th>C(county_name)[T.DUTCHESS]</th>
#       <th>C(county_name)[T.ERIE]</th>
#       <th>C(county_name)[T.HERKIMER]</th>
#       <th>C(county_name)[T.JEFFERSON]</th>
#       <th>C(county_name)[T.KINGS]</th>
#       <th>C(county_name)[T.MADISON]</th>
#       <th>C(county_name)[T.MONROE]</th>
#       <th>C(county_name)[T.NASSAU]</th>
#       <th>C(county_name)[T.NEW YORK]</th>
#       <th>C(county_name)[T.NIAGARA]</th>
#       <th>C(county_name)[T.ONEIDA]</th>
#       <th>C(county_name)[T.ONONDAGA]</th>
#       <th>C(county_name)[T.ONTARIO]</th>
#       <th>C(county_name)[T.ORANGE]</th>
#       <th>C(county_name)[T.OSWEGO]</th>
#       <th>C(county_name)[T.OTHER]</th>
#       <th>C(county_name)[T.OTSEGO]</th>
#       <th>C(county_name)[T.QUEENS]</th>
#       <th>C(county_name)[T.RENSSELAER]</th>
#       <th>C(county_name)[T.ROCKLAND]</th>
#       <th>C(county_name)[T.SAINT LAWRENCE]</th>
#       <th>C(county_name)[T.SARATOGA]</th>
#       <th>C(county_name)[T.STEUBEN]</th>
#       <th>C(county_name)[T.SUFFOLK]</th>
#       <th>C(county_name)[T.SULLIVAN]</th>
#       <th>C(county_name)[T.ULSTER]</th>
#       <th>C(county_name)[T.WASHINGTON]</th>
#       <th>C(county_name)[T.WAYNE]</th>
#       <th>C(county_name)[T.WESTCHESTER]</th>
#       <th>C(membership_desc)[T.2013 Total Cohort - 6 Year Outcome - August 2019]</th>
#       <th>C(membership_desc)[T.2014 Total Cohort - 5 Year Outcome]</th>
#       <th>C(membership_desc)[T.2014 Total Cohort - 5 Year Outcome - August 2019]</th>
#       <th>C(membership_desc)[T.2015 Total Cohort - 4 Year Outcome]</th>
#       <th>C(membership_desc)[T.2015 Total Cohort - 4 Year Outcome - August 2019]</th>
#       <th>C(nrc_desc)[T.Low Needs]</th>
#       <th>C(nrc_desc)[T.Other]</th>
#       <th>C(nrc_desc)[T.Rural High Needs]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1.556674</td>
#       <td>1.439241</td>
#       <td>-1.203165</td>
#       <td>1.795464</td>
#       <td>0.594673</td>
#       <td>1.619218</td>
#       <td>0.240588</td>
#       <td>0.961980</td>
#       <td>-0.660607</td>
#       <td>1.836021</td>
#       <td>1.105788</td>
#       <td>1.554668</td>
#       <td>0.642314</td>
#       <td>-0.588644</td>
#       <td>-0.538319</td>
#       <td>high</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>-2.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>

# %% [markdown]
# ### Drop All Zero Columns
# This will make our models more efficient.

# %%
bad_columns = []
for c in  data_prep.columns:
    if data_prep[c].sum() == 0:
      bad_columns.append(c)
      data_prep.drop(columns=c, inplace=True)

# %%
bad_columns
# Out:
# ['agg_hash_3',
#  'agg_hash_4',
#  'agg_hash_5',
#  'agg_hash_6',
#  'agg_hash_7',
#  'agg_hash_8',
#  'agg_hash_11',
#  'agg_hash_13',
#  'agg_hash_14',
#  'agg_hash_15',
#  'agg_hash_16',
#  'agg_hash_17',
#  'agg_hash_18',
#  'agg_hash_19',
#  'agg_hash_20',
#  'agg_hash_22',
#  'agg_hash_23',
#  'agg_hash_24',
#  'agg_hash_25',
#  'agg_hash_26',
#  'agg_hash_30',
#  'agg_hash_31',
#  'agg_hash_33',
#  'agg_hash_34',
#  'agg_hash_35',
#  'agg_hash_36',
#  'agg_hash_37',
#  'agg_hash_38',
#  'agg_hash_40',
#  'agg_hash_41',
#  'agg_hash_43',
#  'agg_hash_45',
#  'agg_hash_46',
#  'agg_hash_48',
#  'agg_hash_50',
#  'agg_hash_52',
#  'agg_hash_55',
#  'agg_hash_56',
#  'agg_hash_59',
#  'agg_hash_61',
#  'agg_hash_62',
#  'agg_hash_63',
#  'agg_hash_64',
#  'agg_hash_65',
#  'agg_hash_66',
#  'agg_hash_68',
#  'agg_hash_69',
#  'agg_hash_74',
#  'agg_hash_76',
#  'agg_hash_77',
#  'agg_hash_78',
#  'agg_hash_79',
#  'agg_hash_80',
#  'agg_hash_83',
#  'agg_hash_84',
#  'agg_hash_85',
#  'agg_hash_87',
#  'agg_hash_90',
#  'agg_hash_91',
#  'agg_hash_92',
#  'agg_hash_94',
#  'agg_hash_95',
#  'agg_hash_96',
#  'agg_hash_97',
#  'agg_hash_98',
#  'agg_hash_99']

# %% [markdown]
# # Prepared Data Review
# We will review our prepared data to ensure we have actually improved it through our transformations.

# %% [markdown]
# ### nyc_ind

# %%
data_prep.nyc_ind.value_counts()

# %% [markdown]
# We have reduced the non-nyc class by roughly half, but only reduced the nyc class by a quarter. This is likely due to dropping rows with missing data which were more prevalent in non-nyc school reports.

# %% [markdown]
# ### enroll_cnt

# %%
distbox(1,data_prep)
# Out:
# Skewness: 0.023515
# Kurtosis: -0.573553
# count    3.967400e+04
# mean     3.912463e-15
# std      1.000013e+00
# min     -1.990947e+00
# 25%     -7.128094e-01
# 50%      2.404844e-02
# 75%      7.269130e-01
# max      2.960901e+00
# Name: enroll_cnt, dtype: float64
# Nullcount: 0.000000

# %% [markdown]
# This feature is now Gaussian, which should be easier for our models to interpret.
# ### grad_cnt

# %%
distbox(2,data_prep)
# Out:
# Skewness: 0.005268
# Kurtosis: -0.317403
# count    3.967400e+04
# mean     1.077317e-15
# std      1.000013e+00
# min     -3.079111e+00
# 25%     -7.166318e-01
# 50%      1.667774e-02
# 75%      7.103035e-01
# max      3.186279e+00
# Name: grad_cnt, dtype: float64
# Nullcount: 0.000000

# %% [markdown]
# Normalizing and standardizing this feature has improved the skew and shape dramatically.
# ### grd_pct

# %%
distbox(3,data_prep)
# Out:
# Skewness: -0.491204
# Kurtosis: -0.685276
# count    3.967400e+04
# mean     2.115216e-15
# std      1.000013e+00
# min     -2.266169e+00
# 25%     -6.995823e-01
# 50%      1.505791e-01
# 75%      7.985921e-01
# max      1.428338e+00
# Name: grad_pct, dtype: float64
# Nullcount: 0.000000

# %% [markdown]
# Our transformation has improved the skew and shape of grad_pct.
# ### local_cnt

# %%
distbox(4,data_prep)
# Out:
# Skewness: 0.053227
# Kurtosis: -0.618121
# count    3.967400e+04
# mean    -2.723436e-15
# std      1.000013e+00
# min     -1.596883e+00
# 25%     -7.930121e-01
# 50%      9.570248e-02
# 75%      7.277351e-01
# max      2.645622e+00
# Name: local_cnt, dtype: float64
# Nullcount: 0.000000

# %% [markdown]
# Our transformation has improved the skew and shape of local_cnt.
# ### local_pct

# %%
distbox(5,data_prep)
# Out:
# Skewness: -0.014733
# Kurtosis: -0.505537
# count    3.967400e+04
# mean     1.200526e-16
# std      1.000013e+00
# min     -1.609430e+00
# 25%     -6.503470e-01
# 50%      1.472552e-01
# 75%      6.826212e-01
# max      3.031881e+00
# Name: local_pct, dtype: float64
# Nullcount: 0.000000

# %% [markdown]
# Our transformation has improved the skew and shape of local_pct.
# ### reg_adv_cnt

# %%
distbox(6,data_prep)
# Out:
# Skewness: 0.000935
# Kurtosis: -0.032148
# count    3.967400e+04
# mean     1.504595e-15
# std      1.000013e+00
# min     -2.686419e+00
# 25%     -6.859193e-01
# 50%      1.102659e-02
# 75%      6.536636e-01
# max      3.154719e+00
# Name: reg_cnt, dtype: float64
# Nullcount: 0.000000

# %% [markdown]
# Our transformation has improved the skew and shape of reg_adv_cnt.
# ### reg_adv_pct

# %%
distbox(7,data_prep)
# Out:
# Skewness: 0.050013
# Kurtosis: 0.776143
# count    3.967400e+04
# mean    -6.404809e-15
# std      1.000013e+00
# min     -2.873765e+00
# 25%     -5.782298e-01
# 50%      1.094388e-02
# 75%      5.796296e-01
# max      3.076191e+00
# Name: reg_pct, dtype: float64
# Nullcount: 0.000000

# %% [markdown]
# Our transformation hasn't improved the skew and shape of reg_adv_pct much, but it has changed the scale to be in line with other features.
# ### non_diploma_credential_cnt

# %%
distbox(8,data_prep)
# Out:
# Skewness: -0.005711
# Kurtosis: -0.734341
# count    3.967400e+04
# mean    -1.901936e-15
# std      1.000013e+00
# min     -1.670955e+00
# 25%     -7.523044e-01
# 50%      2.509421e-02
# 75%      7.352389e-01
# max      2.918505e+00
# Name: reg_adv_cnt, dtype: float64
# Nullcount: 0.000000

# %% [markdown]
# Our transformation reduced the distance between the outliers dramatically, and fixed the skew problem.
#
# ### non_diploma_credential_pct

# %%
distbox(9,data_prep)
# Out:
# Skewness: -0.306184
# Kurtosis: -0.803661
# count    3.967400e+04
# mean     3.208402e-15
# std      1.000013e+00
# min     -1.773224e+00
# 25%     -6.606075e-01
# 50%      1.144225e-01
# 75%      7.582462e-01
# max      2.179549e+00
# Name: reg_adv_pct, dtype: float64
# Nullcount: 0.000000

# %% [markdown]
# Our transformation reduced the distance between the outliers dramatically, and fixed the skew problem.
#
# ### still_enr_cnt

# %%
distbox(10,data_prep)
# Out:
# Skewness: 0.430680
# Kurtosis: -1.463213
# count    3.967400e+04
# mean     2.421897e-15
# std      1.000013e+00
# min     -8.869371e-01
# 25%     -8.869371e-01
# 50%     -8.869371e-01
# 75%      1.030762e+00
# max      2.002962e+00
# Name: non_diploma_credential_cnt, dtype: float64
# Nullcount: 0.000000

# %% [markdown]
# Our transformation reduced the distance between the outliers dramatically, and fixed the skew problem.
#
# ### still_enr_pct

# %%
distbox(11,data_prep)
# Out:
# Skewness: 0.550715
# Kurtosis: -1.462178
# count    3.967400e+04
# mean    -2.294405e-14
# std      1.000013e+00
# min     -8.118377e-01
# 25%     -8.118377e-01
# 50%     -8.118377e-01
# 75%      1.105788e+00
# max      1.857452e+00
# Name: non_diploma_credential_pct, dtype: float64
# Nullcount: 0.000000

# %% [markdown]
# Our transformation reduced the distance between the outliers dramatically, and fixed the skew problem.
#
# ### ged_cnt

# %%
distbox(12,data_prep)
# Out:
# Skewness: 0.216159
# Kurtosis: -1.107285
# count    3.967400e+04
# mean    -1.422336e-14
# std      1.000013e+00
# min     -1.205229e+00
# 25%     -1.205229e+00
# 50%      1.361756e-01
# 75%      7.113122e-01
# max      2.223487e+00
# Name: still_enr_cnt, dtype: float64
# Nullcount: 0.000000

# %% [markdown]
# Our transformation reduced the distance between the outliers dramatically, and fixed the skew problem.
#
# ### ged_pct

# %%
distbox(13,data_prep)
# Out:
# Skewness: 0.099895
# Kurtosis: -1.270407
# count    3.967400e+04
# mean     1.805226e-14
# std      1.000013e+00
# min     -1.206531e+00
# 25%     -1.206531e+00
# 50%      1.394214e-02
# 75%      7.692194e-01
# max      2.392295e+00
# Name: still_enr_pct, dtype: float64
# Nullcount: 0.000000

# %% [markdown]
# Our transformation reduced skew and kurtosis dramatically, though the distribution still doesn't look great, though it does look less bad. Outliers seem to have had a very large effect on this feature,
#
# ### dropout_cnt

# %%
distbox(14,data_prep)
# Out:
# Skewness: 1.139871
# Kurtosis: -0.636969
# count    3.967400e+04
# mean    -1.004848e-14
# std      1.000013e+00
# min     -5.886440e-01
# 25%     -5.886440e-01
# 50%     -5.886440e-01
# 75%      1.388370e+00
# max      1.940388e+00
# Name: ged_cnt, dtype: float64
# Nullcount: 0.000000

# %% [markdown]
# Our transformation reduced the distance between the outliers dramatically, and fixed the skew problem.
#
# ### dropout_pct

# %%
distbox(15,data_prep)
# Out:
# Skewness: 1.324905
# Kurtosis: -0.231488
# count    3.967400e+04
# mean    -3.860407e-14
# std      1.000013e+00
# min     -5.383187e-01
# 25%     -5.383187e-01
# 50%     -5.383187e-01
# 75%     -5.383187e-01
# max      1.976141e+00
# Name: ged_pct, dtype: float64
# Nullcount: 0.000000

# %% [markdown]
# Our transformation reduced the distance between the outliers dramatically, and fixed the skew problem. This may look most like our response variable, though with everything normalized it is hard to tell.
#
# ### dropout_pct_level (TARGET)

# %%
distbox(16,data_prep, 'categorical', normalize=False)
# Out:
# high      14880
# low       13315
# medium    11479
# Name: dropout_pct_level, dtype: int64
# Nullcount: 0.000000

# %% [markdown]
# Our classes are roughly equal. We will stratify our test/train splits still, and see if any of the models have class balancing hyper-parameters.
#
# ## Correlation Analysis
#
# Analyses of non-categorical co-linearity

# %%
plt.figure(figsize=(14,10))
sns.heatmap(data_prep.iloc[:,:17].corr(),cmap='coolwarm',annot=False);
plt.xticks(rotation=40 , rotation_mode='anchor',ha="right");

# %% [markdown]
# We see many correlated features here. Some are cnt/pct pairs, which haven't changed from the original dataset. Others are much more predictive after standardization and normalization. We will eliminate many of these features before attempting a model.

# %% [markdown]
# # Classifier Modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score
from sklearn import metrics

from sklearn.metrics import classification_report

from sklearn.ensemble import RandomForestClassifier

import rfpimp 
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Test Train Split

# %%
# Separate features and response variables. 

X = data_prep.drop(['dropout_pct_level'], axis = 1)# assign the explanatory variables to a Python object
y = data_prep.dropout_pct_level# assign the response variable to a Python object

# Produces train and test splits.
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    random_state=42,
    stratify = y
    )

# %% [markdown]
# ## Null Hypothesis
# This is a measure of how wrong the classifier would be if it predicted just the majority class. The formula is (Actual:Number/Total Sample).

# %%
(len(X_train)-y_train.str.contains('high').sum())/len(X_train)#total count minus positive count divided by total count
# Out:
# 0.6249369853806083

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# Because the models we are utilizing do some feature selection naturally, we will focus our efforts on removing redundant IE extremely collinear and very low variance.
#
# step one: drop redundant features:
# - From previous work on this data, we know that cnt and pct variables are highly collinear we will keep the pct where there are both.
#
# step 2: variance
# - using sklearns variance feature selector, we will drop any columns with a variance less than .01
#
# notes: we are starting with 109 features

# %%
#1. dropping cnt columns
dropping_columns = ['grad_cnt',
                    'local_cnt',
                    'reg_adv_cnt',
                    'non_diploma_credential_cnt',
                    'still_enr_cnt',
                    'ged_cnt',
                    'reg_cnt']

X_train.drop(columns=dropping_columns,inplace=True)
X_test.drop(columns=dropping_columns,inplace=True)

# %%
#2.  variacne selector

from sklearn.feature_selection import VarianceThreshold
selector = VarianceThreshold(threshold=.05)
selector.fit(X_train)
# Out:
# VarianceThreshold(threshold=0.05)

# %%
features_names = selector.get_feature_names_out()

features_names = features_names.tolist()

# %% [markdown]
# we are now left with 47 features for use in our models. before we build the models we will transform training and testing splits.

# %%
X_train = pd.DataFrame(selector.transform(X_train), columns = features_names)
X_test = pd.DataFrame(selector.transform(X_test), columns = features_names)

# %% [markdown]
# ## Model Building
# to tune the hyper-parameters for each of our models, we will utilize grid search approaches
# code referenced from here:  https://towardsdatascience.com/hyperparameter-tuning-the-random-forest-in-python-using-scikit-learn-28d2aa77dd74

# %% [markdown]
# ### Decision Tree
#
# we will first perform a cost complexity analysis to determine the range for our hyper-parameters we will then grid search to find the optimal values.

# %% [markdown]
# #### Optimizing Parameters

# %%
#Importing the Decision tree classifier from the sklearn library.
dtc = DecisionTreeClassifier(criterion = 'entropy')

path = dtc.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities


fig, ax = plt.subplots()

ax.plot(ccp_alphas[-100:-1], impurities[-100:-1], marker="o", drawstyle="steps-post")
ax.set_xlabel("effective alpha")
ax.set_ylabel("total impurity of leaves")
ax.set_title("Total Impurity vs effective alpha for training set")
# Out:
# Text(0.5, 1.0, 'Total Impurity vs effective alpha for training set')

# %%
ccp_alphas.shape
# Out:
# (1091,)

# %%
clfs = []
for ccp_alpha in ccp_alphas[-100:-1]:
    clf_alpha = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha, criterion = 'entropy')
    clf_alpha.fit(X_train, y_train)
    clfs.append(clf_alpha)
print(
    "Number of nodes in the last tree is: {} with ccp_alpha: {}".format(
        clfs[-1].tree_.node_count, ccp_alphas[-1]
    )
)
# Out:
# Number of nodes in the last tree is: 3 with ccp_alpha: 0.4090137843997461

# %%
#clfs = clfs[:-1]
ccp_alphas = ccp_alphas[-100:-1]

node_counts = [dtc.tree_.node_count for dtc in clfs]
depth = [dtc.tree_.max_depth for dtc in clfs]

#ploting
fig, ax = plt.subplots(2, 1)
ax[0].plot(ccp_alphas, node_counts, marker="o", drawstyle="steps-post")
ax[0].set_xlabel("alpha")
ax[0].set_ylabel("number of nodes")
ax[0].set_title("Number of nodes vs alpha")
ax[1].plot(ccp_alphas, depth, marker="o", drawstyle="steps-post")
ax[1].set_xlabel("alpha")
ax[1].set_ylabel("depth of tree")
ax[1].set_title("Depth vs alpha")
fig.tight_layout()

# %%
del clfs

# %% [markdown]
# **Conclusion:**
# based on the analysis above, we will do a grid search of the number of nodes between 100-200 and tree depth between 5-9 to find our ideal parameters

# %% [markdown]
# #### Grid Search

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# Create the parameter grid based on the results of random search 
param_grid = { 
            'criterion': ['gini','entropy'],
            'max_depth': range(5,10), #range determined evaluation above
            'max_features': ['sqrt', 'log2',None],
            'max_leaf_nodes': range(100,201,20)#range determined evaluation above
            }

# Create a base model
dtc = DecisionTreeClassifier()

# Instantiate the grid search model
grid_search = GridSearchCV(
                        estimator = dtc, 
                        param_grid = param_grid, 
                        cv = 5, # cross folds
                        n_jobs = -1,
                        pre_dispatch='4*n_jobs',
                        verbose = 1,
                        error_score='raise'
                            )

# %%
grid_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# GridSearchCV(cv=5, error_score='raise', estimator=DecisionTreeClassifier(),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(5, 10),
#                          'max_features': ['sqrt', 'log2', None],
#                          'max_leaf_nodes': range(100, 201, 20)},
#              pre_dispatch='4*n_jobs', verbose=1)

# %% [markdown]
# outputting our testing results

# %%
pd.DataFrame(grid_search.cv_results_).sort_values('rank_test_score')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mean_fit_time</th>
#       <th>std_fit_time</th>
#       <th>mean_score_time</th>
#       <th>std_score_time</th>
#       <th>param_criterion</th>
#       <th>param_max_depth</th>
#       <th>param_max_features</th>
#       <th>param_max_leaf_nodes</th>
#       <th>params</th>
#       <th>split0_test_score</th>
#       <th>split1_test_score</th>
#       <th>split2_test_score</th>
#       <th>split3_test_score</th>
#       <th>split4_test_score</th>
#       <th>mean_test_score</th>
#       <th>std_test_score</th>
#       <th>rank_test_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>89</th>
#       <td>0.208801</td>
#       <td>0.003547</td>
#       <td>0.012550</td>
#       <td>0.000061</td>
#       <td>gini</td>
#       <td>9</td>
#       <td>None</td>
#       <td>200</td>
#       <td>{'criterion': 'gini', 'max_depth': 9, 'max_fea...</td>
#       <td>0.899345</td>
#       <td>0.898841</td>
#       <td>0.904218</td>
#       <td>0.900185</td>
#       <td>0.900017</td>
#       <td>0.900521</td>
#       <td>0.001910</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>88</th>
#       <td>0.206308</td>
#       <td>0.002248</td>
#       <td>0.012557</td>
#       <td>0.000221</td>
#       <td>gini</td>
#       <td>9</td>
#       <td>None</td>
#       <td>180</td>
#       <td>{'criterion': 'gini', 'max_depth': 9, 'max_fea...</td>
#       <td>0.899177</td>
#       <td>0.896656</td>
#       <td>0.904890</td>
#       <td>0.900185</td>
#       <td>0.898841</td>
#       <td>0.899950</td>
#       <td>0.002725</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>87</th>
#       <td>0.203632</td>
#       <td>0.000829</td>
#       <td>0.012444</td>
#       <td>0.000071</td>
#       <td>gini</td>
#       <td>9</td>
#       <td>None</td>
#       <td>160</td>
#       <td>{'criterion': 'gini', 'max_depth': 9, 'max_fea...</td>
#       <td>0.897832</td>
#       <td>0.894808</td>
#       <td>0.903042</td>
#       <td>0.898504</td>
#       <td>0.896824</td>
#       <td>0.898202</td>
#       <td>0.002723</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>86</th>
#       <td>0.199864</td>
#       <td>0.001750</td>
#       <td>0.012464</td>
#       <td>0.000106</td>
#       <td>gini</td>
#       <td>9</td>
#       <td>None</td>
#       <td>140</td>
#       <td>{'criterion': 'gini', 'max_depth': 9, 'max_fea...</td>
#       <td>0.896824</td>
#       <td>0.894640</td>
#       <td>0.902537</td>
#       <td>0.894640</td>
#       <td>0.895144</td>
#       <td>0.896757</td>
#       <td>0.003000</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>179</th>
#       <td>0.208046</td>
#       <td>0.013384</td>
#       <td>0.011451</td>
#       <td>0.002120</td>
#       <td>entropy</td>
#       <td>9</td>
#       <td>None</td>
#       <td>200</td>
#       <td>{'criterion': 'entropy', 'max_depth': 9, 'max_...</td>
#       <td>0.889934</td>
#       <td>0.893127</td>
#       <td>0.894472</td>
#       <td>0.900689</td>
#       <td>0.898841</td>
#       <td>0.895413</td>
#       <td>0.003891</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>92</th>
#       <td>0.064774</td>
#       <td>0.000821</td>
#       <td>0.013803</td>
#       <td>0.001730</td>
#       <td>entropy</td>
#       <td>5</td>
#       <td>sqrt</td>
#       <td>140</td>
#       <td>{'criterion': 'entropy', 'max_depth': 5, 'max_...</td>
#       <td>0.513863</td>
#       <td>0.591833</td>
#       <td>0.523609</td>
#       <td>0.595866</td>
#       <td>0.706604</td>
#       <td>0.586355</td>
#       <td>0.068953</td>
#       <td>176</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0.064966</td>
#       <td>0.002500</td>
#       <td>0.013028</td>
#       <td>0.000537</td>
#       <td>gini</td>
#       <td>5</td>
#       <td>log2</td>
#       <td>180</td>
#       <td>{'criterion': 'gini', 'max_depth': 5, 'max_fea...</td>
#       <td>0.569988</td>
#       <td>0.680054</td>
#       <td>0.504957</td>
#       <td>0.595026</td>
#       <td>0.560746</td>
#       <td>0.582154</td>
#       <td>0.057124</td>
#       <td>177</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.063814</td>
#       <td>0.002523</td>
#       <td>0.012903</td>
#       <td>0.000281</td>
#       <td>gini</td>
#       <td>5</td>
#       <td>log2</td>
#       <td>140</td>
#       <td>{'criterion': 'gini', 'max_depth': 5, 'max_fea...</td>
#       <td>0.543102</td>
#       <td>0.625945</td>
#       <td>0.625609</td>
#       <td>0.558730</td>
#       <td>0.529155</td>
#       <td>0.576508</td>
#       <td>0.041302</td>
#       <td>178</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>0.071237</td>
#       <td>0.001808</td>
#       <td>0.013044</td>
#       <td>0.000293</td>
#       <td>gini</td>
#       <td>5</td>
#       <td>sqrt</td>
#       <td>100</td>
#       <td>{'criterion': 'gini', 'max_depth': 5, 'max_fea...</td>
#       <td>0.547639</td>
#       <td>0.513023</td>
#       <td>0.554361</td>
#       <td>0.669803</td>
#       <td>0.585112</td>
#       <td>0.573988</td>
#       <td>0.053105</td>
#       <td>179</td>
#     </tr>
#     <tr>
#       <th>100</th>
#       <td>0.064955</td>
#       <td>0.002639</td>
#       <td>0.012803</td>
#       <td>0.000343</td>
#       <td>entropy</td>
#       <td>5</td>
#       <td>log2</td>
#       <td>180</td>
#       <td>{'criterion': 'entropy', 'max_depth': 5, 'max_...</td>
#       <td>0.546463</td>
#       <td>0.556881</td>
#       <td>0.482104</td>
#       <td>0.641909</td>
#       <td>0.510670</td>
#       <td>0.547605</td>
#       <td>0.054102</td>
#       <td>180</td>
#     </tr>
#   </tbody>
# </table>
# <p>180 rows × 17 columns</p>
# </div>

# %% [markdown]
# moving the best fit model into its own object

# %%
best_dtc = grid_search.best_estimator_

best_dtc
# Out:
# DecisionTreeClassifier(max_depth=9, max_leaf_nodes=200)

# %% [markdown]
# #### Metrics

# %%
y_pred = best_dtc.predict(X_train)
print('Accuracy Score on train data: ', accuracy_score(y_true=y_train, y_pred=best_dtc.predict(X_train)))
# Out:
# Accuracy Score on train data:  0.9150058813644766

# %%
print(classification_report(y_train,best_dtc.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#         high       0.93      0.94      0.93     11160
#          low       0.96      0.92      0.94      9986
#       medium       0.85      0.88      0.86      8609
#
#     accuracy                           0.92     29755
#    macro avg       0.91      0.91      0.91     29755
# weighted avg       0.92      0.92      0.92     29755

# %%
vals = cross_val_score(best_dtc,X_train,y_train,cv=5 )
print(f'dtc crossval scores: \n mean:{vals.mean()}\n std:{vals.std()}')
# Out:
# dtc crossval scores:
#  mean:0.9004873130566292
#  std:0.001992236643962909

# %% [markdown]
# ### Random Forest
#
# Because of the large number of potential options for our hyper parameters and the increased time in training. We will utilize random grid search instead of the more exhaustive grid search to tune our hyper parameters.

# %% [markdown]
# #### Optimizing Parameters

# %%
# using a random grid search to estimate our hyper perameters
random_grid = {'bootstrap': [True, False],
 'max_depth': [5, 10, None],    # values selected based on decision tree work above  
 'max_features': ['auto', 'sqrt'],
 'min_samples_leaf': [1, 2, 4],
 'min_samples_split': [2, 5, 10],
 'n_estimators': [50,100, 200, 400, 600, 800, 1000]}

# %%
from sklearn.model_selection import RandomizedSearchCV
# substantiating classifier 
rf = RandomForestClassifier()

rf_parms = RandomizedSearchCV(
                    estimator = rf, 
                    param_distributions = random_grid, 
                    n_iter = 20,
                    random_state=100,
                    cv = 5, 
                    n_jobs = -1,
                    pre_dispatch='4*n_jobs',#for every thread, ensure there are 4 bits of data to work on
                    verbose = 2,
                    error_score='raise'
                        )

# %%
rf_parms.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=5, error_score='raise',
#                    estimator=RandomForestClassifier(), n_iter=20, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [5, 10, None],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [50, 100, 200, 400, 600,
#                                                          800, 1000]},
#                    pre_dispatch='4*n_jobs', random_state=100, verbose=2)

# %%
rf_parms.best_params_
# Out:
# {'n_estimators': 1000,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': None,
#  'bootstrap': False}

# %%
rf_model = rf_parms.best_estimator_

# %% [markdown]
# #### Metrics

# %%
print('Accuracy Score on train data: ', accuracy_score(y_true=y_train, y_pred=rf_model.predict(X_train)))
# Out:
# Accuracy Score on train data:  1.0

# %%
print(classification_report(y_train,rf_model.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#         high       1.00      1.00      1.00     11160
#          low       1.00      1.00      1.00      9986
#       medium       1.00      1.00      1.00      8609
#
#     accuracy                           1.00     29755
#    macro avg       1.00      1.00      1.00     29755
# weighted avg       1.00      1.00      1.00     29755

# %%
vals = cross_val_score(rf_model,X_train,y_train,cv=5 )
print(f'rf crossval scores: \n mean:{vals.mean()}\n std:{vals.std()}')
# Out:
# rf crossval scores:
#  mean:0.9375567131574526
#  std:0.00126465385462788

# %% [markdown]
# ### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc = GradientBoostingClassifier(loss='deviance',#loss function 'deviance' is used for classifiers
                                 learning_rate=0.1,#shrinks the contribution of each tree
                                 n_estimators=100,#The number of boosting stages to perform. Gradient boosting is fairly robust to over-fitting so a large number usually results in better performance.
                                 subsample=1.0,# using 1.0 here as anything less would result in stochastic gradient boosting, which we are saving for the next model
                                 criterion='friedman_mse'#‘friedman_mse’ is generally the best as it can provide a better approximation in some cases
                                )
gbc.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %% [markdown]
# #### Optimizing Parameters

# %%
print('Accuracy Score on train data: ', accuracy_score(y_true=y_train, y_pred=gbc.predict(X_train)))
# Out:
# Accuracy Score on train data:  0.9135943538901025

# %%
print(classification_report(y_train,gbc.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#         high       0.93      0.97      0.95     11160
#          low       0.97      0.89      0.92      9986
#       medium       0.85      0.88      0.86      8609
#
#     accuracy                           0.91     29755
#    macro avg       0.91      0.91      0.91     29755
# weighted avg       0.92      0.91      0.91     29755

# %%
#check squared_error as criterion
gbc = GradientBoostingClassifier(loss='deviance',#loss function 'deviance' is used for classifiers
                                 learning_rate=0.1,#shrinks the contribution of each tree
                                 n_estimators=100,#The number of boosting stages to perform. Gradient boosting is fairly robust to over-fitting so a large number usually results in better performance.
                                 subsample=1.0,# using 1.0 here as anything less would result in stochastic gradient boosting, which we are saving for the next model
                                 criterion='squared_error',#‘friedman_mse’ is generally the best as it can provide a better approximation in some cases
                                )
gbc.fit(X_train, y_train)
print(classification_report(y_train,gbc.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#         high       0.93      0.97      0.95     11160
#          low       0.97      0.89      0.92      9986
#       medium       0.85      0.88      0.86      8609
#
#     accuracy                           0.91     29755
#    macro avg       0.91      0.91      0.91     29755
# weighted avg       0.92      0.91      0.91     29755

# %% [markdown]
# No improvements were seen. We will stick with the friedman_mse criterion.

# %%
#test learning rate. code inspired by https://stackabuse.com/gradient-boosting-classifiers-in-python-with-scikit-learn/
lr_list = [0.05, 0.075, 0.1, 0.25, 0.5, 0.75, 1]#we selected a range that we belive will allow for acceptable performance/accureacy tradeoffs to test

for learning_rate in lr_list:
    gb_clf = GradientBoostingClassifier(n_estimators=20, learning_rate=learning_rate, max_features=2, max_depth=2, random_state=0)
    gb_clf.fit(X_train, y_train)

    print("Learning rate: ", learning_rate)
    print("Accuracy score (training): {0:.3f}".format(gb_clf.score(X_train, y_train)))
# Out:
# Learning rate:  0.05
# Accuracy score (training): 0.645
# Learning rate:  0.075
# Accuracy score (training): 0.674
# Learning rate:  0.1
# Accuracy score (training): 0.687
# Learning rate:  0.25
# Accuracy score (training): 0.714
# Learning rate:  0.5
# Accuracy score (training): 0.732
# Learning rate:  0.75
# Accuracy score (training): 0.754
# Learning rate:  1
# Accuracy score (training): 0.767

# %% [markdown]
# We will increase our learning rate to 1

# %%
 #testing max_depth parameters
md_list = [5,10,15,20]

for max_depth in md_list:
    gb_clf = GradientBoostingClassifier(n_estimators=20, max_depth=max_depth, max_features=2,  random_state=0)
    gb_clf.fit(X_train, y_train)

    print("Max Depth: ", max_depth)
    print("Accuracy score (training): {0:.3f}".format(gb_clf.score(X_train, y_train)))
# Out:
# Max Depth:  5
# Accuracy score (training): 0.739
# Max Depth:  10
# Accuracy score (training): 0.845
# Max Depth:  15
# Accuracy score (training): 0.978
# Max Depth:  20
# Accuracy score (training): 1.000

# %% [markdown]
# We will set our max depth to 20.

# %%
gbc = GradientBoostingClassifier(loss='deviance',#loss function 'deviance' is used for classifiers
                                 learning_rate=1,#shrinks the contribution of each tree
                                 n_estimators=100,#The number of boosting stages to perform. Gradient boosting is fairly robust to over-fitting so a large number usually results in better performance.
                                 subsample=1.0,# using 1.0 here as anything less would result in stochastic gradient boosting, which we are saving for the next model
                                 criterion='friedman_mse',#‘friedman_mse’ is generally the best as it can provide a better approximation in some cases
                                 max_depth=20
                                )
gbc.fit(X_train, y_train)
print('Accuracy Score on train data: ', accuracy_score(y_true=y_train, y_pred=gbc.predict(X_train)))
# Out:
# Accuracy Score on train data:  1.0

# %%
print(classification_report(y_train,gbc.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#         high       1.00      1.00      1.00     11160
#          low       1.00      1.00      1.00      9986
#       medium       1.00      1.00      1.00      8609
#
#     accuracy                           1.00     29755
#    macro avg       1.00      1.00      1.00     29755
# weighted avg       1.00      1.00      1.00     29755

# %%
vals = cross_val_score(gbc,X_train,y_train,cv=5 )
print(f'gbc crossval scores: \n mean:{vals.mean()}\n std:{vals.std()}')
# Out:
# gbc crossval scores:
#  mean:0.9544278272559235
#  std:0.0038280446278458335

# %% [markdown]
# ### Stochastic Gradient Descent

# %% [markdown]
# #### Optimizing Parameters

# %%
from sklearn.linear_model import SGDClassifier

sgdc = SGDClassifier(max_iter=1000, 
tol=1e-3,
penalty='l1', 
random_state=42,
class_weight='balanced'
)
sgdc.fit(X_train, y_train)
# Out:
# SGDClassifier(class_weight='balanced', penalty='l1', random_state=42)

# %% [markdown]
# #### Metrics

# %%
print('Accuracy Score on train data: ', accuracy_score(y_true=y_train, y_pred=sgdc.predict(X_train)))
# Out:
# Accuracy Score on train data:  0.7714669803394387

# %%
print(classification_report(y_test,sgdc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#         high       0.79      0.95      0.86      3720
#          low       0.73      0.88      0.80      3329
#       medium       0.79      0.40      0.53      2870
#
#     accuracy                           0.77      9919
#    macro avg       0.77      0.74      0.73      9919
# weighted avg       0.77      0.77      0.75      9919

# %%
vals = cross_val_score(sgdc,X_train,y_train,cv=5 )
print(f'sgdc crossval scores: \n mean:{vals.mean()}\n std:{vals.std()}')
# Out:
# sgdc crossval scores:
#  mean:0.7599058981683751
#  std:0.0487613579913406

# %% [markdown]
# ### Extreme Gradient Boost

# %%
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
xgbc = xgb.XGBClassifier(random_state=42,)
X_train.columns = X_train.columns.str.replace('[', '')#dropping brackets from column names which interfere with model
X_train.columns = X_train.columns.str.replace(']', '')#dropping brackets from column names which interfere with model
label_encoder = LabelEncoder()#transforming str response variable to a numeric input as the model requires.
label_encoder = label_encoder.fit(y_train)
label_encoded_y = label_encoder.transform(y_train)

# %%
xgbc.fit(X_train, y_train)
# Out:
# [04:08:55] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=2,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %% [markdown]
# #### Metrics

# %%
print('Accuracy Score on train data: ', accuracy_score(y_true=y_train, y_pred=xgbc.predict(X_train)))
# Out:
# Accuracy Score on train data:  0.9951940850277264

# %%
print(classification_report(y_test,xgbc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#         high       0.98      0.99      0.99      3720
#          low       0.98      0.96      0.97      3329
#       medium       0.94      0.96      0.95      2870
#
#     accuracy                           0.97      9919
#    macro avg       0.97      0.97      0.97      9919
# weighted avg       0.97      0.97      0.97      9919

# %%
vals = cross_val_score(xgbc,X_train,y_train,cv=5 )
print(f'xgbc crossval scores: \n mean:{vals.mean()}\n std:{vals.std()}')
# Out:
# [04:09:11] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:09:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:09:36] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:09:48] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:10:01] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# xgbc crossval scores:
#  mean:0.966761888758192
#  std:0.003075434795559299

# %% [markdown]
# # Model Selection

# %% [markdown]
# ## Model Summary
#
# | Model| Precision (macro avg)|Recall (macro avg)|F1 (macro avg)| Accuracy| Crossval Mean| Crossval Std |
# |     :-:     |               :-:    |  :-:  |   :-:     |       :-:    | :-:          | :--:        |
# | Null Error Rate             |   -  |    -   |  -    |          0.625    |       -      |   -       |
# | Decision Tree               | .91  | .91    | .91   |          .92      |    .900      | .0019    |
# | Random Forest               |  1   |  1     |   1   |           1       |    .937      | .0016   |
# | Gradient Boosting           |   1  |  1     |   1   |          .91      |    .953      | .0032  |
# | Stochastic Gradient Descent | .77  | .74    | .73   |          .77      |    .763      | .0275  |
# | XGBoost                     | .97  | .97    | .97   |          .97      |    .967      | .0031  |

# %% [markdown]
# ## Preferred Model
#
# The XGBoost classifier is our highest performing model across all metrics. Even though we need to encode our response variable in order to run the model, which makes it even less legible, we prefer it for its scores. We will now modify our testing sets to be in line with the training set, and view their scores.

# %%
X_test.columns = X_test.columns.str.replace('[', '')#dropping brackets from column names which interfere with model
X_test.columns = X_test.columns.str.replace(']', '')#dropping brackets from column names which interfere with model
label_encoder = LabelEncoder()#transforming str response variable to a numeric input as the model requires.
label_encoder = label_encoder.fit(y_test)
label_encoded_y = label_encoder.transform(y_test)
print(classification_report(y_test,xgbc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#         high       0.98      0.99      0.99      3720
#          low       0.98      0.96      0.97      3329
#       medium       0.94      0.96      0.95      2870
#
#     accuracy                           0.97      9919
#    macro avg       0.97      0.97      0.97      9919
# weighted avg       0.97      0.97      0.97      9919

# %% [markdown]
# The XGBoost model scores on the test set are perfectly in line with the training set, which indicates that it generalizes very well.

# %% [markdown]
# # Conclusion
# It was fascinating to see the journey machine learning has taken from decision trees to extreme gradient boosting. The models improved steadily with the exception of stochastic gradient descent. This is likely due to the slightly random nature of jumps, which we could not optimize for better results.
#
# We can see why many books and articles recommend using XGBoost, although going through this exercise was still useful. After all, there is no free lunch.
#
# Potential next steps include;
# - Optimizing feature selection
# - Attempting to train a different model to find natural groupings, instead of our artificial low, medium, high
